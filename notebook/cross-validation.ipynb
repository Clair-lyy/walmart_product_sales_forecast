# %%
import pandas as pd
import numpy as np
from datetime import datetime
import tqdm
import re
from sklearn.multioutput import MultiOutputRegressor
import seaborn as sns
import matplotlib.pyplot as plt

from warnings import simplefilter

import matplotlib.pyplot as plt
import lightgbm as lgb

from statsmodels.tsa.deterministic import DeterministicProcess, CalendarFourier
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import os

import seaborn as sns; sns.set()
import gc

from sklearn import preprocessing

from typing import Union
from tqdm.notebook import tqdm_notebook as tqdm

import warnings
warnings.simplefilter('ignore')

# %%
groups = [['HOBBIES', 'CA_1'],
       ['HOUSEHOLD', 'CA_1'],
       ['FOODS', 'CA_1'],
       ['HOBBIES', 'CA_2'],
       ['HOUSEHOLD', 'CA_2'],
       ['FOODS', 'CA_2'],
       ['HOBBIES', 'CA_3'],
       ['HOUSEHOLD', 'CA_3'],
       ['FOODS', 'CA_3'],
       ['HOBBIES', 'CA_4'],
       ['HOUSEHOLD', 'CA_4'],
       ['FOODS', 'CA_4'],
       ['HOBBIES', 'TX_1'],
       ['HOUSEHOLD', 'TX_1'],
       ['FOODS', 'TX_1'],
       ['HOBBIES', 'TX_2'],
       ['HOUSEHOLD', 'TX_2'],
       ['FOODS', 'TX_2'],
       ['HOBBIES', 'TX_3'],
       ['HOUSEHOLD', 'TX_3'],
       ['FOODS', 'TX_3'],
       ['HOBBIES', 'WI_1'],
       ['HOUSEHOLD', 'WI_1'],
       ['FOODS', 'WI_1'],
       ['HOBBIES', 'WI_2'],
       ['HOUSEHOLD', 'WI_2'],
       ['FOODS', 'WI_2'],
       ['HOBBIES', 'WI_3'],
       ['HOUSEHOLD', 'WI_3'],
       ['FOODS', 'WI_3']]

# %%
train_data = pd.read_csv('../data/sales_train_evaluation.csv')
calendar = pd.read_csv('../data/calendar.csv')
prices = pd.read_csv('../data/sell_prices.csv')
submission = pd.read_csv('../data/sample_submission.csv')

# %%
class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, 
                 calendar: pd.DataFrame, prices: pd.DataFrame):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()

        train_df['all_id'] = 'all'  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')]\
                     .columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')]\
                               .columns.tolist()
        
        #valid_target_columns = valid_df.columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], 
                                 axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices

        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)\
                    [valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns]\
                    .set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index()\
                   .rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left',
                                    on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd'])\
                    .unstack(level=2)['value']\
                    .loc[zip(self.train_df.item_id, self.train_df.store_id), :]\
                    .reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns],
                               weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        return (score / scale).map(np.sqrt) 

    def score(self, valid_preds: Union[pd.DataFrame, 
                                       np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape \
               == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, 
                                       columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], 
                                 valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):

            valid_preds_grp = valid_preds.groupby(group_id)[self.valid_target_columns].sum()
            setattr(self, f'lv{i + 1}_valid_preds', valid_preds_grp)
            
            lv_scores = self.rmsse(valid_preds_grp, i + 1)
            setattr(self, f'lv{i + 1}_scores', lv_scores)
            
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, 
                                  sort=False).prod(axis=1)
            
            all_scores.append(lv_scores.sum())
            
        self.all_scores = all_scores

        return np.mean(all_scores)

# %%
def get_wrmsse_score(train_df, pred_df, split_day):
    delta = 1941 - split_day
    train_fold_df = train_df.iloc[:, : -delta]
    if delta == 28:
        valid_fold_df = train_df.iloc[:, -delta:]
    else:
        valid_fold_df = train_df.iloc[:, -delta: -delta+28]

    pred_df.rename({f'F{i}': f'd_{split_day+i}' for i in range(1,29)}, axis=1, inplace=True)

    pred_df = submission[['id']].merge(pred_df, on = 'id')

    evaluator = WRMSSEEvaluator(train_fold_df, valid_fold_df, calendar, prices)
    return evaluator.score(pred_df[[col for col in pred_df.columns if re.match('d_\d{1,4}', col)]])

# %%
weight_scale_df = pd.read_csv('../data/weight_scale_df.csv')
weight_scale_dict = {
    f'{item_id}_{store_id}_evaluation': weight/scale for item_id, store_id, weight, scale in weight_scale_df.values
}
weight_scale_dict
# Out:
# {'FOODS_1_001_CA_1_evaluation': 1.1537085781235683e-05,
#  'FOODS_1_001_CA_2_evaluation': 7.73234391658877e-06,
#  'FOODS_1_001_CA_3_evaluation': 4.4913467910992025e-06,
#  'FOODS_1_001_CA_4_evaluation': 5.327285231787002e-06,
#  'FOODS_1_001_TX_1_evaluation': 3.212129107154062e-07,
#  'FOODS_1_001_TX_2_evaluation': 4.3044046130824065e-06,
#  'FOODS_1_001_TX_3_evaluation': 7.321247180659534e-06,
#  'FOODS_1_001_WI_1_evaluation': 8.134406104502398e-06,
#  'FOODS_1_001_WI_2_evaluation': 5.393520304087257e-06,
#  'FOODS_1_001_WI_3_evaluation': 6.6524804995261e-06,
#  'FOODS_1_002_CA_1_evaluation': 2.8488508076891867e-05,
#  'FOODS_1_002_CA_2_evaluation': 3.83300790967364e-05,
#  'FOODS_1_002_CA_3_evaluation': 3.42663189572327e-05,
#  'FOODS_1_002_CA_4_evaluation': 1.1251592257827941e-05,
#  'FOODS_1_002_TX_1_evaluation': 7.020214310815294e-06,
#  'FOODS_1_002_TX_2_evaluation': 1.0039531706153647e-05,
#  'FOODS_1_002_TX_3_evaluation': 2.93023280518152e-05,
#  'FOODS_1_002_WI_1_evaluation': 4.4486785591110184e-05,
#  'FOODS_1_002_WI_2_evaluation': 3.49625729101855e-05,
#  'FOODS_1_002_WI_3_evaluation': 1.2856412099461745e-05,
#  'FOODS_1_003_CA_1_evaluation': 1.1633716903945662e-05,
#  'FOODS_1_003_CA_2_evaluation': 1.0960179468327721e-05,
#  'FOODS_1_003_CA_3_evaluation': 1.3852371141960893e-05,
#  'FOODS_1_003_CA_4_evaluation': 5.425558011380811e-06,
#  'FOODS_1_003_TX_1_evaluation': 1.9190128337069714e-06,
#  'FOODS_1_003_TX_2_evaluation': 1.4825320336104442e-05,
#  'FOODS_1_003_TX_3_evaluation': 0.0,
#  'FOODS_1_003_WI_1_evaluation': 1.0321907392621605e-05,
#  'FOODS_1_003_WI_2_evaluation': 1.2771820165061924e-06,
#  'FOODS_1_003_WI_3_evaluation': 8.552729715233966e-07,
#  'FOODS_1_004_CA_1_evaluation': 0.0,
#  'FOODS_1_004_CA_2_evaluation': 0.0,
#  'FOODS_1_004_CA_3_evaluation': 0.0,
#  'FOODS_1_004_CA_4_evaluation': 0.0,
#  'FOODS_1_004_TX_1_evaluation': 0.0,
#  'FOODS_1_004_TX_2_evaluation': 0.0,
#  'FOODS_1_004_TX_3_evaluation': 0.0,
#  'FOODS_1_004_WI_1_evaluation': 0.0,
#  'FOODS_1_004_WI_2_evaluation': 0.0,
#  'FOODS_1_004_WI_3_evaluation': 0.0,
#  'FOODS_1_005_CA_1_evaluation': 1.4494781690286234e-05,
#  'FOODS_1_005_CA_2_evaluation': 3.648750030454528e-05,
#  'FOODS_1_005_CA_3_evaluation': 1.7914140352257856e-05,
#  'FOODS_1_005_CA_4_evaluation': 2.9740951512428934e-05,
#  'FOODS_1_005_TX_1_evaluation': 7.486857599239409e-06,
#  'FOODS_1_005_TX_2_evaluation': 1.1164972864806608e-05,
#  'FOODS_1_005_TX_3_evaluation': 1.9683017846847363e-05,
#  'FOODS_1_005_WI_1_evaluation': 4.0134233158773205e-05,
#  'FOODS_1_005_WI_2_evaluation': 2.8557996140674306e-05,
#  'FOODS_1_005_WI_3_evaluation': 2.4637032594897252e-05,
#  'FOODS_1_006_CA_1_evaluation': 1.3300387872248424e-05,
#  'FOODS_1_006_CA_2_evaluation': 5.328127563660112e-06,
#  'FOODS_1_006_CA_3_evaluation': 7.075786474999364e-06,
#  'FOODS_1_006_CA_4_evaluation': 9.624169963713586e-06,
#  'FOODS_1_006_TX_1_evaluation': 5.474059517743178e-06,
#  'FOODS_1_006_TX_2_evaluation': 7.519047456734484e-06,
#  'FOODS_1_006_TX_3_evaluation': 5.947551762927118e-06,
#  'FOODS_1_006_WI_1_evaluation': 1.2377645787613616e-05,
#  'FOODS_1_006_WI_2_evaluation': 1.0811233637053084e-05,
#  'FOODS_1_006_WI_3_evaluation': 1.3045800053611542e-05,
#  'FOODS_1_008_CA_1_evaluation': 3.7766884866094573e-06,
#  'FOODS_1_008_CA_2_evaluation': 2.4065406233443197e-05,
#  'FOODS_1_008_CA_3_evaluation': 8.940461086825734e-07,
#  'FOODS_1_008_CA_4_evaluation': 7.3045350394241965e-06,
#  'FOODS_1_008_TX_1_evaluation': 3.7778334581339016e-06,
#  'FOODS_1_008_TX_2_evaluation': 4.499459152322335e-06,
#  'FOODS_1_008_TX_3_evaluation': 7.912035230411861e-06,
#  'FOODS_1_008_WI_1_evaluation': 4.553118526927764e-06,
#  'FOODS_1_008_WI_2_evaluation': 3.688139161626633e-06,
#  'FOODS_1_008_WI_3_evaluation': 4.480676575819838e-06,
#  'FOODS_1_009_CA_1_evaluation': 0.0,
#  'FOODS_1_009_CA_2_evaluation': 0.0,
#  'FOODS_1_009_CA_3_evaluation': 0.0,
#  'FOODS_1_009_CA_4_evaluation': 0.0,
#  'FOODS_1_009_TX_1_evaluation': 0.0,
#  'FOODS_1_009_TX_2_evaluation': 0.0,
#  'FOODS_1_009_TX_3_evaluation': 0.0,
#  'FOODS_1_009_WI_1_evaluation': 0.0,
#  'FOODS_1_009_WI_2_evaluation': 0.0,
#  'FOODS_1_009_WI_3_evaluation': 6.910756385258325e-07,
#  'FOODS_1_010_CA_1_evaluation': 1.2141278294918373e-05,
#  'FOODS_1_010_CA_2_evaluation': 8.059471843336618e-06,
#  'FOODS_1_010_CA_3_evaluation': 2.7602314367558472e-05,
#  'FOODS_1_010_CA_4_evaluation': 4.134646786525754e-06,
#  'FOODS_1_010_TX_1_evaluation': 4.179042642460273e-05,
#  'FOODS_1_010_TX_2_evaluation': 1.77746642683341e-05,
#  'FOODS_1_010_TX_3_evaluation': 2.633036236234615e-05,
#  'FOODS_1_010_WI_1_evaluation': 7.068705613159591e-05,
#  'FOODS_1_010_WI_2_evaluation': 1.0349461081778391e-05,
#  'FOODS_1_010_WI_3_evaluation': 2.8872978701858736e-05,
#  'FOODS_1_011_CA_1_evaluation': 1.6016375932126395e-05,
#  'FOODS_1_011_CA_2_evaluation': 1.811231917305145e-05,
#  'FOODS_1_011_CA_3_evaluation': 1.8972513597817207e-05,
#  'FOODS_1_011_CA_4_evaluation': 1.8726654827655692e-05,
#  'FOODS_1_011_TX_1_evaluation': 5.429893784184611e-06,
#  'FOODS_1_011_TX_2_evaluation': 2.6517996862640774e-06,
#  'FOODS_1_011_TX_3_evaluation': 6.466099602160297e-06,
#  'FOODS_1_011_WI_1_evaluation': 1.7496723749812716e-05,
#  'FOODS_1_011_WI_2_evaluation': 1.2987323193939001e-05,
#  'FOODS_1_011_WI_3_evaluation': 7.1317436566183305e-06,
#  'FOODS_1_012_CA_1_evaluation': 3.5229205966219006e-05,
#  'FOODS_1_012_CA_2_evaluation': 7.748674401420883e-05,
#  'FOODS_1_012_CA_3_evaluation': 9.06420599645662e-06,
#  'FOODS_1_012_CA_4_evaluation': 6.039161081976603e-05,
#  'FOODS_1_012_TX_1_evaluation': 8.569187959566306e-05,
#  'FOODS_1_012_TX_2_evaluation': 8.646946177873143e-05,
#  'FOODS_1_012_TX_3_evaluation': 9.40588598270381e-05,
#  'FOODS_1_012_WI_1_evaluation': 6.901757509442105e-05,
#  'FOODS_1_012_WI_2_evaluation': 4.663158322825883e-05,
#  'FOODS_1_012_WI_3_evaluation': 5.4786405126846235e-05,
#  'FOODS_1_013_CA_1_evaluation': 1.0816260898517181e-05,
#  'FOODS_1_013_CA_2_evaluation': 6.1361357102955515e-06,
#  'FOODS_1_013_CA_3_evaluation': 6.375497046804944e-06,
#  'FOODS_1_013_CA_4_evaluation': 5.881843199958933e-06,
#  'FOODS_1_013_TX_1_evaluation': 2.856857080926085e-06,
#  'FOODS_1_013_TX_2_evaluation': 3.4682824657627508e-06,
#  'FOODS_1_013_TX_3_evaluation': 4.828142187433697e-06,
#  'FOODS_1_013_WI_1_evaluation': 5.500349848676279e-06,
#  'FOODS_1_013_WI_2_evaluation': 3.6049958470745733e-06,
#  'FOODS_1_013_WI_3_evaluation': 3.3806865164874237e-06,
#  'FOODS_1_014_CA_1_evaluation': 3.823847111719136e-06,
#  'FOODS_1_014_CA_2_evaluation': 2.159835296918784e-06,
#  'FOODS_1_014_CA_3_evaluation': 4.5820865813618695e-06,
#  'FOODS_1_014_CA_4_evaluation': 2.0761089601458487e-06,
#  'FOODS_1_014_TX_1_evaluation': 1.821685967438873e-06,
#  'FOODS_1_014_TX_2_evaluation': 2.519264493190586e-06,
#  'FOODS_1_014_TX_3_evaluation': 6.6869427241839136e-06,
#  'FOODS_1_014_WI_1_evaluation': 4.901467659119591e-06,
#  'FOODS_1_014_WI_2_evaluation': 7.661712100406328e-06,
#  'FOODS_1_014_WI_3_evaluation': 5.81442091778022e-06,
#  'FOODS_1_015_CA_1_evaluation': 1.1135786331621152e-05,
#  'FOODS_1_015_CA_2_evaluation': 1.914387506732361e-05,
#  'FOODS_1_015_CA_3_evaluation': 1.6814594801067224e-05,
#  'FOODS_1_015_CA_4_evaluation': 6.782103177189539e-06,
#  'FOODS_1_015_TX_1_evaluation': 7.827397771496406e-06,
#  'FOODS_1_015_TX_2_evaluation': 6.646020672873292e-06,
#  'FOODS_1_015_TX_3_evaluation': 1.0487257220899827e-05,
#  'FOODS_1_015_WI_1_evaluation': 5.232110324813681e-06,
#  'FOODS_1_015_WI_2_evaluation': 1.2711846651219379e-05,
#  'FOODS_1_015_WI_3_evaluation': 1.321316138685889e-06,
#  'FOODS_1_016_CA_1_evaluation': 1.3581678343009194e-06,
#  'FOODS_1_016_CA_2_evaluation': 6.35338651471405e-06,
#  'FOODS_1_016_CA_3_evaluation': 7.232948359003009e-06,
#  'FOODS_1_016_CA_4_evaluation': 6.542350933561724e-06,
#  'FOODS_1_016_TX_1_evaluation': 5.740961415064962e-06,
#  'FOODS_1_016_TX_2_evaluation': 7.0901991348509114e-06,
#  'FOODS_1_016_TX_3_evaluation': 8.132355882487292e-06,
#  'FOODS_1_016_WI_1_evaluation': 6.132322365373796e-06,
#  'FOODS_1_016_WI_2_evaluation': 1.6453900121325115e-05,
#  'FOODS_1_016_WI_3_evaluation': 4.676774726239614e-06,
#  'FOODS_1_017_CA_1_evaluation': 8.973292576435723e-06,
#  'FOODS_1_017_CA_2_evaluation': 1.0652481535925603e-05,
#  'FOODS_1_017_CA_3_evaluation': 1.6933206203602755e-05,
#  'FOODS_1_017_CA_4_evaluation': 8.504085274152987e-06,
#  'FOODS_1_017_TX_1_evaluation': 7.858974417135504e-06,
#  'FOODS_1_017_TX_2_evaluation': 8.021533102581837e-06,
#  'FOODS_1_017_TX_3_evaluation': 1.1778073761243097e-05,
#  'FOODS_1_017_WI_1_evaluation': 1.400280991639135e-05,
#  'FOODS_1_017_WI_2_evaluation': 1.3305896697603425e-05,
#  'FOODS_1_017_WI_3_evaluation': 1.4340792568122926e-05,
#  'FOODS_1_018_CA_1_evaluation': 9.027577463473628e-06,
#  'FOODS_1_018_CA_2_evaluation': 1.358702796937282e-05,
#  'FOODS_1_018_CA_3_evaluation': 1.109220679079585e-05,
#  'FOODS_1_018_CA_4_evaluation': 8.665637764474818e-06,
#  'FOODS_1_018_TX_1_evaluation': 1.3306370963951608e-05,
#  'FOODS_1_018_TX_2_evaluation': 1.4140947557529977e-05,
#  'FOODS_1_018_TX_3_evaluation': 2.1599101858603936e-05,
#  'FOODS_1_018_WI_1_evaluation': 1.3249823317153694e-05,
#  'FOODS_1_018_WI_2_evaluation': 1.643083019980343e-05,
#  'FOODS_1_018_WI_3_evaluation': 1.3212788134969981e-05,
#  'FOODS_1_019_CA_1_evaluation': 1.2470641363020897e-05,
#  'FOODS_1_019_CA_2_evaluation': 1.0894720847826308e-05,
#  'FOODS_1_019_CA_3_evaluation': 7.118540243305511e-06,
#  'FOODS_1_019_CA_4_evaluation': 1.3600699360182643e-05,
#  'FOODS_1_019_TX_1_evaluation': 8.167036326878419e-06,
#  'FOODS_1_019_TX_2_evaluation': 6.568975581287652e-06,
#  'FOODS_1_019_TX_3_evaluation': 1.4308601028865673e-05,
#  'FOODS_1_019_WI_1_evaluation': 9.070054701187867e-06,
#  'FOODS_1_019_WI_2_evaluation': 9.400540387797628e-06,
#  'FOODS_1_019_WI_3_evaluation': 9.565627059278684e-06,
#  'FOODS_1_020_CA_1_evaluation': 1.5359262460690798e-05,
#  'FOODS_1_020_CA_2_evaluation': 1.2043915806194503e-05,
#  'FOODS_1_020_CA_3_evaluation': 1.1473779234379396e-05,
#  'FOODS_1_020_CA_4_evaluation': 2.373605576694434e-05,
#  'FOODS_1_020_TX_1_evaluation': 6.605027654209787e-06,
#  'FOODS_1_020_TX_2_evaluation': 7.2921265652562695e-06,
#  'FOODS_1_020_TX_3_evaluation': 6.148202976125017e-06,
#  'FOODS_1_020_WI_1_evaluation': 2.2322377765652355e-05,
#  'FOODS_1_020_WI_2_evaluation': 1.5588952420784397e-05,
#  'FOODS_1_020_WI_3_evaluation': 1.391328895065496e-05,
#  'FOODS_1_021_CA_1_evaluation': 1.0533089345041777e-06,
#  'FOODS_1_021_CA_2_evaluation': 4.024528455996977e-06,
#  'FOODS_1_021_CA_3_evaluation': 3.836112106085105e-06,
#  'FOODS_1_021_CA_4_evaluation': 3.764494423876401e-06,
#  'FOODS_1_021_TX_1_evaluation': 2.4226480529881064e-06,
#  'FOODS_1_021_TX_2_evaluation': 1.4126286573375889e-07,
#  'FOODS_1_021_TX_3_evaluation': 1.3348738240458684e-07,
#  'FOODS_1_021_WI_1_evaluation': 2.1303336920292057e-06,
#  'FOODS_1_021_WI_2_evaluation': 2.0991359413995312e-06,
#  'FOODS_1_021_WI_3_evaluation': 2.2032004431612246e-06,
#  'FOODS_1_022_CA_1_evaluation': 4.763450352073237e-06,
#  'FOODS_1_022_CA_2_evaluation': 2.3678711135530866e-05,
#  'FOODS_1_022_CA_3_evaluation': 1.7748880587589077e-05,
#  'FOODS_1_022_CA_4_evaluation': 0.0,
#  'FOODS_1_022_TX_1_evaluation': 1.0805204152745604e-05,
#  'FOODS_1_022_TX_2_evaluation': 1.9427904972353313e-05,
#  'FOODS_1_022_TX_3_evaluation': 0.0,
#  'FOODS_1_022_WI_1_evaluation': 2.475182600616249e-06,
#  'FOODS_1_022_WI_2_evaluation': 2.725786721645047e-05,
#  'FOODS_1_022_WI_3_evaluation': 0.0,
#  'FOODS_1_023_CA_1_evaluation': 5.003339455545035e-06,
#  'FOODS_1_023_CA_2_evaluation': 3.642238538854671e-05,
#  'FOODS_1_023_CA_3_evaluation': 7.334855791475045e-05,
#  'FOODS_1_023_CA_4_evaluation': 4.329108652644211e-05,
#  'FOODS_1_023_TX_1_evaluation': 4.943742709168306e-05,
#  'FOODS_1_023_TX_2_evaluation': 6.59222539524426e-05,
#  'FOODS_1_023_TX_3_evaluation': 4.002436873499098e-05,
#  'FOODS_1_023_WI_1_evaluation': 2.1915149733297917e-05,
#  'FOODS_1_023_WI_2_evaluation': 3.412953698436718e-05,
#  'FOODS_1_023_WI_3_evaluation': 3.268624920519665e-05,
#  'FOODS_1_024_CA_1_evaluation': 1.476388202025967e-06,
#  'FOODS_1_024_CA_2_evaluation': 3.0288919537052708e-05,
#  'FOODS_1_024_CA_3_evaluation': 3.083516062085278e-05,
#  'FOODS_1_024_CA_4_evaluation': 1.970485061282839e-05,
#  'FOODS_1_024_TX_1_evaluation': 1.2391875619904809e-05,
#  'FOODS_1_024_TX_2_evaluation': 9.03143064148652e-06,
#  'FOODS_1_024_TX_3_evaluation': 9.581028804770283e-06,
#  'FOODS_1_024_WI_1_evaluation': 2.0386639254719594e-05,
#  'FOODS_1_024_WI_2_evaluation': 2.709295735506697e-05,
#  'FOODS_1_024_WI_3_evaluation': 1.5287749812484357e-05,
#  'FOODS_1_025_CA_1_evaluation': 1.522603339534138e-05,
#  'FOODS_1_025_CA_2_evaluation': 1.584625833104381e-05,
#  'FOODS_1_025_CA_3_evaluation': 1.0501012828421434e-05,
#  'FOODS_1_025_CA_4_evaluation': 1.0083579907136776e-05,
#  'FOODS_1_025_TX_1_evaluation': 1.154309210870606e-05,
#  'FOODS_1_025_TX_2_evaluation': 1.53218515970911e-05,
#  'FOODS_1_025_TX_3_evaluation': 8.152183602080431e-06,
#  'FOODS_1_025_WI_1_evaluation': 0.0,
#  'FOODS_1_025_WI_2_evaluation': 1.0444440105682302e-05,
#  'FOODS_1_025_WI_3_evaluation': 2.8809702169295416e-05,
#  'FOODS_1_026_CA_1_evaluation': 2.88016269483595e-05,
#  'FOODS_1_026_CA_2_evaluation': 1.940393049652324e-05,
#  'FOODS_1_026_CA_3_evaluation': 2.652346398964778e-05,
#  'FOODS_1_026_CA_4_evaluation': 1.7020039164630428e-05,
#  'FOODS_1_026_TX_1_evaluation': 2.1194481164621243e-05,
#  'FOODS_1_026_TX_2_evaluation': 8.47850488410964e-06,
#  'FOODS_1_026_TX_3_evaluation': 1.1542078458692468e-05,
#  'FOODS_1_026_WI_1_evaluation': 3.28544131405099e-05,
#  'FOODS_1_026_WI_2_evaluation': 3.798094271943588e-05,
#  'FOODS_1_026_WI_3_evaluation': 1.5886770414984873e-05,
#  'FOODS_1_027_CA_1_evaluation': 1.1694254387158728e-05,
#  'FOODS_1_027_CA_2_evaluation': 1.214016062659095e-05,
#  'FOODS_1_027_CA_3_evaluation': 7.088050514639441e-06,
#  'FOODS_1_027_CA_4_evaluation': 1.0419855554933974e-05,
#  'FOODS_1_027_TX_1_evaluation': 6.368550064195942e-06,
#  'FOODS_1_027_TX_2_evaluation': 6.020934739024012e-06,
#  'FOODS_1_027_TX_3_evaluation': 6.816505796762365e-06,
#  'FOODS_1_027_WI_1_evaluation': 8.871831039229872e-06,
#  'FOODS_1_027_WI_2_evaluation': 1.7339337380524754e-05,
#  'FOODS_1_027_WI_3_evaluation': 1.194246275207769e-05,
#  'FOODS_1_028_CA_1_evaluation': 8.611952440641534e-06,
#  'FOODS_1_028_CA_2_evaluation': 8.308111048618703e-06,
#  'FOODS_1_028_CA_3_evaluation': 8.597988834929179e-06,
#  'FOODS_1_028_CA_4_evaluation': 7.596618590062218e-06,
#  'FOODS_1_028_TX_1_evaluation': 6.23233328875953e-06,
#  'FOODS_1_028_TX_2_evaluation': 2.7079898479778587e-06,
#  'FOODS_1_028_TX_3_evaluation': 1.4054675734800354e-05,
#  'FOODS_1_028_WI_1_evaluation': 2.0305190688440888e-05,
#  'FOODS_1_028_WI_2_evaluation': 2.88966535234451e-05,
#  'FOODS_1_028_WI_3_evaluation': 2.2487570866087305e-05,
#  'FOODS_1_029_CA_1_evaluation': 1.3423257963652541e-05,
#  'FOODS_1_029_CA_2_evaluation': 1.3653228635865392e-05,
#  'FOODS_1_029_CA_3_evaluation': 2.0120111734241106e-05,
#  'FOODS_1_029_CA_4_evaluation': 4.891589295317148e-06,
#  'FOODS_1_029_TX_1_evaluation': 1.1168919192547017e-05,
#  'FOODS_1_029_TX_2_evaluation': 1.3566495958148758e-05,
#  'FOODS_1_029_TX_3_evaluation': 5.6721092197208445e-06,
#  'FOODS_1_029_WI_1_evaluation': 5.275377936056857e-06,
#  'FOODS_1_029_WI_2_evaluation': 5.048589552793393e-06,
#  'FOODS_1_029_WI_3_evaluation': 1.4232278357423444e-05,
#  'FOODS_1_030_CA_1_evaluation': 1.1866558942617565e-05,
#  'FOODS_1_030_CA_2_evaluation': 1.2565200464516422e-05,
#  'FOODS_1_030_CA_3_evaluation': 1.0764128255814722e-05,
#  'FOODS_1_030_CA_4_evaluation': 1.895827201820322e-05,
#  'FOODS_1_030_TX_1_evaluation': 1.0517098201143377e-05,
#  'FOODS_1_030_TX_2_evaluation': 8.457849379051223e-06,
#  'FOODS_1_030_TX_3_evaluation': 1.0389249929810104e-05,
#  'FOODS_1_030_WI_1_evaluation': 4.797983900382664e-06,
#  'FOODS_1_030_WI_2_evaluation': 2.72164637089985e-05,
#  'FOODS_1_030_WI_3_evaluation': 4.640772296937092e-06,
#  'FOODS_1_031_CA_1_evaluation': 9.48089802225376e-06,
#  'FOODS_1_031_CA_2_evaluation': 2.3290891862773218e-05,
#  'FOODS_1_031_CA_3_evaluation': 2.4893681116225358e-05,
#  'FOODS_1_031_CA_4_evaluation': 1.4092861217976882e-05,
#  'FOODS_1_031_TX_1_evaluation': 2.142255136897249e-05,
#  'FOODS_1_031_TX_2_evaluation': 8.246373384099505e-06,
#  'FOODS_1_031_TX_3_evaluation': 9.50918295671001e-06,
#  'FOODS_1_031_WI_1_evaluation': 1.6644867225628405e-05,
#  'FOODS_1_031_WI_2_evaluation': 1.590979239761354e-05,
#  'FOODS_1_031_WI_3_evaluation': 1.9633236707963692e-05,
#  'FOODS_1_032_CA_1_evaluation': 1.4171553523364597e-06,
#  'FOODS_1_032_CA_2_evaluation': 7.033117108161091e-06,
#  'FOODS_1_032_CA_3_evaluation': 8.335729886651953e-06,
#  'FOODS_1_032_CA_4_evaluation': 9.914598851508247e-06,
#  'FOODS_1_032_TX_1_evaluation': 1.0374075369275465e-05,
#  'FOODS_1_032_TX_2_evaluation': 3.990964612814244e-06,
#  'FOODS_1_032_TX_3_evaluation': 6.274582734453846e-06,
#  'FOODS_1_032_WI_1_evaluation': 1.1280768326765314e-05,
#  'FOODS_1_032_WI_2_evaluation': 1.2999439375074435e-05,
#  'FOODS_1_032_WI_3_evaluation': 6.459143555476306e-06,
#  'FOODS_1_033_CA_1_evaluation': 3.0284426899519854e-05,
#  'FOODS_1_033_CA_2_evaluation': 4.61939501539004e-06,
#  'FOODS_1_033_CA_3_evaluation': 1.4431263250557927e-05,
#  'FOODS_1_033_CA_4_evaluation': 1.0477258777114839e-05,
#  'FOODS_1_033_TX_1_evaluation': 4.907857759951931e-06,
#  'FOODS_1_033_TX_2_evaluation': 0.0,
#  'FOODS_1_033_TX_3_evaluation': 2.4783324078684743e-06,
#  'FOODS_1_033_WI_1_evaluation': 3.5336809586664653e-06,
#  'FOODS_1_033_WI_2_evaluation': 5.401338028064434e-06,
#  'FOODS_1_033_WI_3_evaluation': 1.6730469930296378e-05,
#  'FOODS_1_034_CA_1_evaluation': 1.0373634234718911e-05,
#  'FOODS_1_034_CA_2_evaluation': 4.812486090505077e-05,
#  'FOODS_1_034_CA_3_evaluation': 2.0962916541589813e-05,
#  'FOODS_1_034_CA_4_evaluation': 2.4354269156986196e-05,
#  'FOODS_1_034_TX_1_evaluation': 4.228291216345798e-05,
#  'FOODS_1_034_TX_2_evaluation': 2.2534198865442862e-05,
#  'FOODS_1_034_TX_3_evaluation': 3.086889741988591e-05,
#  'FOODS_1_034_WI_1_evaluation': 7.440513797637905e-05,
#  'FOODS_1_034_WI_2_evaluation': 2.7649814233209643e-05,
#  'FOODS_1_034_WI_3_evaluation': 4.025623176632536e-05,
#  'FOODS_1_035_CA_1_evaluation': 1.4497822368133205e-05,
#  'FOODS_1_035_CA_2_evaluation': 2.904835244845212e-05,
#  'FOODS_1_035_CA_3_evaluation': 1.4118806949527363e-05,
#  'FOODS_1_035_CA_4_evaluation': 2.0385590903854902e-05,
#  'FOODS_1_035_TX_1_evaluation': 1.1709717205232933e-05,
#  'FOODS_1_035_TX_2_evaluation': 4.338042947695043e-06,
#  'FOODS_1_035_TX_3_evaluation': 1.544228312583693e-05,
#  'FOODS_1_035_WI_1_evaluation': 1.8463903945436596e-05,
#  'FOODS_1_035_WI_2_evaluation': 4.609957739311199e-06,
#  'FOODS_1_035_WI_3_evaluation': 6.085169933671522e-06,
#  'FOODS_1_036_CA_1_evaluation': 1.0963904336560967e-05,
#  'FOODS_1_036_CA_2_evaluation': 6.19526821965999e-06,
#  'FOODS_1_036_CA_3_evaluation': 1.0214733920913901e-05,
#  'FOODS_1_036_CA_4_evaluation': 1.1320118346801951e-05,
#  'FOODS_1_036_TX_1_evaluation': 9.757743120783802e-06,
#  'FOODS_1_036_TX_2_evaluation': 1.4775065422683467e-06,
#  'FOODS_1_036_TX_3_evaluation': 1.064861544777369e-05,
#  'FOODS_1_036_WI_1_evaluation': 7.496934509366192e-06,
#  'FOODS_1_036_WI_2_evaluation': 1.5090711856334063e-05,
#  'FOODS_1_036_WI_3_evaluation': 1.970662387643651e-05,
#  'FOODS_1_037_CA_1_evaluation': 2.6817251407404976e-05,
#  'FOODS_1_037_CA_2_evaluation': 2.5739497023369383e-05,
#  'FOODS_1_037_CA_3_evaluation': 2.5839089739076644e-05,
#  'FOODS_1_037_CA_4_evaluation': 1.0675892467310413e-05,
#  'FOODS_1_037_TX_1_evaluation': 1.1419997632433194e-05,
#  'FOODS_1_037_TX_2_evaluation': 1.330600357781747e-05,
#  'FOODS_1_037_TX_3_evaluation': 1.0080389613931312e-05,
#  'FOODS_1_037_WI_1_evaluation': 8.717159263158943e-06,
#  'FOODS_1_037_WI_2_evaluation': 8.353718343314299e-06,
#  'FOODS_1_037_WI_3_evaluation': 1.0077294031643345e-05,
#  'FOODS_1_038_CA_1_evaluation': 3.147882609643445e-05,
#  'FOODS_1_038_CA_2_evaluation': 4.5958812591804e-05,
#  'FOODS_1_038_CA_3_evaluation': 4.9912695607205916e-05,
#  'FOODS_1_038_CA_4_evaluation': 3.368966311942114e-05,
#  'FOODS_1_038_TX_1_evaluation': 2.04264679459384e-05,
#  'FOODS_1_038_TX_2_evaluation': 1.735786014660329e-05,
#  'FOODS_1_038_TX_3_evaluation': 4.588848185868729e-05,
#  'FOODS_1_038_WI_1_evaluation': 3.4284968160402e-05,
#  'FOODS_1_038_WI_2_evaluation': 2.8468460040011317e-05,
#  'FOODS_1_038_WI_3_evaluation': 5.980178337649743e-06,
#  'FOODS_1_039_CA_1_evaluation': 6.924971717803237e-06,
#  'FOODS_1_039_CA_2_evaluation': 1.2023392939024133e-05,
#  'FOODS_1_039_CA_3_evaluation': 9.898748087942393e-06,
#  'FOODS_1_039_CA_4_evaluation': 2.4845282278498844e-05,
#  'FOODS_1_039_TX_1_evaluation': 7.598732215071905e-06,
#  'FOODS_1_039_TX_2_evaluation': 5.844996169434446e-06,
#  'FOODS_1_039_TX_3_evaluation': 5.509125163559436e-06,
#  'FOODS_1_039_WI_1_evaluation': 5.604581191774555e-06,
#  'FOODS_1_039_WI_2_evaluation': 3.1555966631901595e-06,
#  'FOODS_1_039_WI_3_evaluation': 5.561467360629356e-06,
#  'FOODS_1_040_CA_1_evaluation': 1.3102992904013871e-05,
#  'FOODS_1_040_CA_2_evaluation': 1.108135426644143e-05,
#  'FOODS_1_040_CA_3_evaluation': 4.380298589521076e-06,
#  'FOODS_1_040_CA_4_evaluation': 1.1555238918538083e-05,
#  'FOODS_1_040_TX_1_evaluation': 6.473694046903923e-06,
#  'FOODS_1_040_TX_2_evaluation': 1.167552557838161e-06,
#  'FOODS_1_040_TX_3_evaluation': 0.0,
#  'FOODS_1_040_WI_1_evaluation': 9.718633772537891e-06,
#  'FOODS_1_040_WI_2_evaluation': 1.3569210043174063e-05,
#  'FOODS_1_040_WI_3_evaluation': 1.0150370244798583e-05,
#  'FOODS_1_041_CA_1_evaluation': 1.0368474824340699e-05,
#  'FOODS_1_041_CA_2_evaluation': 1.012995407345681e-05,
#  'FOODS_1_041_CA_3_evaluation': 1.0910302378582702e-05,
#  'FOODS_1_041_CA_4_evaluation': 8.683975261674932e-06,
#  'FOODS_1_041_TX_1_evaluation': 7.33343853656839e-06,
#  'FOODS_1_041_TX_2_evaluation': 6.898568775669581e-06,
#  'FOODS_1_041_TX_3_evaluation': 1.7335888940493072e-06,
#  'FOODS_1_041_WI_1_evaluation': 8.562735042829338e-06,
#  'FOODS_1_041_WI_2_evaluation': 8.040660324520069e-06,
#  'FOODS_1_041_WI_3_evaluation': 8.180226101272465e-06,
#  'FOODS_1_042_CA_1_evaluation': 4.505367031079259e-06,
#  'FOODS_1_042_CA_2_evaluation': 4.284214662240016e-06,
#  'FOODS_1_042_CA_3_evaluation': 5.6283191099254205e-06,
#  'FOODS_1_042_CA_4_evaluation': 5.564092013760739e-06,
#  'FOODS_1_042_TX_1_evaluation': 8.680254683221085e-06,
#  'FOODS_1_042_TX_2_evaluation': 6.226792215230453e-06,
#  'FOODS_1_042_TX_3_evaluation': 8.998685148792235e-06,
#  'FOODS_1_042_WI_1_evaluation': 7.800996628668224e-06,
#  'FOODS_1_042_WI_2_evaluation': 5.739954075527012e-06,
#  'FOODS_1_042_WI_3_evaluation': 6.136241997169402e-06,
#  'FOODS_1_043_CA_1_evaluation': 0.0,
#  'FOODS_1_043_CA_2_evaluation': 0.0,
#  'FOODS_1_043_CA_3_evaluation': 0.0,
#  'FOODS_1_043_CA_4_evaluation': 0.0,
#  'FOODS_1_043_TX_1_evaluation': 0.0,
#  'FOODS_1_043_TX_2_evaluation': 0.0,
#  'FOODS_1_043_TX_3_evaluation': 0.0,
#  'FOODS_1_043_WI_1_evaluation': 0.0,
#  'FOODS_1_043_WI_2_evaluation': 0.0,
#  'FOODS_1_043_WI_3_evaluation': 0.0,
#  'FOODS_1_044_CA_1_evaluation': 6.307075211950795e-06,
#  'FOODS_1_044_CA_2_evaluation': 3.070181100730832e-06,
#  'FOODS_1_044_CA_3_evaluation': 3.42524700998406e-06,
#  'FOODS_1_044_CA_4_evaluation': 3.7949953692935597e-06,
#  'FOODS_1_044_TX_1_evaluation': 2.8942766508384595e-06,
#  'FOODS_1_044_TX_2_evaluation': 3.9300456061666894e-06,
#  'FOODS_1_044_TX_3_evaluation': 1.2793100832373354e-05,
#  'FOODS_1_044_WI_1_evaluation': 1.6042925232965418e-05,
#  'FOODS_1_044_WI_2_evaluation': 2.0193140335029297e-05,
#  'FOODS_1_044_WI_3_evaluation': 2.241165708553272e-05,
#  'FOODS_1_045_CA_1_evaluation': 4.972200173642728e-06,
#  'FOODS_1_045_CA_2_evaluation': 7.278129394872733e-06,
#  'FOODS_1_045_CA_3_evaluation': 3.325149667472286e-06,
#  'FOODS_1_045_CA_4_evaluation': 2.814655996132069e-06,
#  'FOODS_1_045_TX_1_evaluation': 1.212556460071103e-05,
#  'FOODS_1_045_TX_2_evaluation': 5.70569174032428e-06,
#  'FOODS_1_045_TX_3_evaluation': 5.443172129567422e-06,
#  'FOODS_1_045_WI_1_evaluation': 6.288054766495059e-06,
#  'FOODS_1_045_WI_2_evaluation': 7.611976820009434e-06,
#  'FOODS_1_045_WI_3_evaluation': 6.7009455487162935e-06,
#  'FOODS_1_046_CA_1_evaluation': 1.067095467518808e-05,
#  'FOODS_1_046_CA_2_evaluation': 8.506579466674566e-06,
#  'FOODS_1_046_CA_3_evaluation': 4.073803352956053e-06,
#  'FOODS_1_046_CA_4_evaluation': 7.989560133932746e-06,
#  'FOODS_1_046_TX_1_evaluation': 3.120184404467302e-06,
#  'FOODS_1_046_TX_2_evaluation': 6.786203480244263e-06,
#  'FOODS_1_046_TX_3_evaluation': 8.793776761564283e-06,
#  'FOODS_1_046_WI_1_evaluation': 7.381981924873763e-06,
#  'FOODS_1_046_WI_2_evaluation': 4.6020751331761946e-06,
#  'FOODS_1_046_WI_3_evaluation': 4.14507207777448e-06,
#  'FOODS_1_047_CA_1_evaluation': 1.2016770513796509e-05,
#  'FOODS_1_047_CA_2_evaluation': 2.3802124623604422e-05,
#  'FOODS_1_047_CA_3_evaluation': 1.557639561145192e-05,
#  'FOODS_1_047_CA_4_evaluation': 2.3086473605904774e-05,
#  'FOODS_1_047_TX_1_evaluation': 1.563194936461867e-05,
#  'FOODS_1_047_TX_2_evaluation': 4.597410135131303e-06,
#  'FOODS_1_047_TX_3_evaluation': 8.677319865154234e-06,
#  'FOODS_1_047_WI_1_evaluation': 1.0741794701035058e-05,
#  'FOODS_1_047_WI_2_evaluation': 3.265514448087567e-06,
#  'FOODS_1_047_WI_3_evaluation': 7.287844449715591e-06,
#  'FOODS_1_048_CA_1_evaluation': 3.2753922434263734e-05,
#  'FOODS_1_048_CA_2_evaluation': 2.800176365387983e-05,
#  'FOODS_1_048_CA_3_evaluation': 2.6407146323569184e-05,
#  'FOODS_1_048_CA_4_evaluation': 1.2325700732391821e-05,
#  'FOODS_1_048_TX_1_evaluation': 1.7261570072704557e-05,
#  'FOODS_1_048_TX_2_evaluation': 2.3612340400178033e-05,
#  'FOODS_1_048_TX_3_evaluation': 1.3876787709335634e-05,
#  'FOODS_1_048_WI_1_evaluation': 2.2938563236782785e-05,
#  'FOODS_1_048_WI_2_evaluation': 1.158427174251837e-05,
#  'FOODS_1_048_WI_3_evaluation': 7.546919255501417e-06,
#  'FOODS_1_049_CA_1_evaluation': 5.565078439502023e-06,
#  'FOODS_1_049_CA_2_evaluation': 6.076279602909673e-06,
#  'FOODS_1_049_CA_3_evaluation': 5.137410743140155e-06,
#  'FOODS_1_049_CA_4_evaluation': 1.0633924694048958e-05,
#  'FOODS_1_049_TX_1_evaluation': 2.5556853273776926e-06,
#  'FOODS_1_049_TX_2_evaluation': 1.0427124436335041e-06,
#  'FOODS_1_049_TX_3_evaluation': 2.963357308117973e-06,
#  'FOODS_1_049_WI_1_evaluation': 8.107834752742351e-06,
#  'FOODS_1_049_WI_2_evaluation': 5.989483038652128e-06,
#  'FOODS_1_049_WI_3_evaluation': 4.151994694176671e-06,
#  'FOODS_1_050_CA_1_evaluation': 3.6366810221303e-05,
#  'FOODS_1_050_CA_2_evaluation': 1.9728667975148916e-05,
#  'FOODS_1_050_CA_3_evaluation': 3.412528510323843e-05,
#  'FOODS_1_050_CA_4_evaluation': 3.251796490096178e-05,
#  'FOODS_1_050_TX_1_evaluation': 3.415707377341648e-05,
#  'FOODS_1_050_TX_2_evaluation': 1.2254290593655785e-05,
#  'FOODS_1_050_TX_3_evaluation': 1.5241926726335369e-05,
#  'FOODS_1_050_WI_1_evaluation': 2.3401227740348635e-05,
#  'FOODS_1_050_WI_2_evaluation': 1.3198662071999981e-05,
#  'FOODS_1_050_WI_3_evaluation': 9.40345885596845e-06,
#  'FOODS_1_051_CA_1_evaluation': 1.1551775819545181e-05,
#  'FOODS_1_051_CA_2_evaluation': 2.1701753584859154e-05,
#  'FOODS_1_051_CA_3_evaluation': 2.2952767904755408e-05,
#  'FOODS_1_051_CA_4_evaluation': 2.0437562207796408e-05,
#  'FOODS_1_051_TX_1_evaluation': 2.2643483026680272e-05,
#  'FOODS_1_051_TX_2_evaluation': 2.721698210190553e-05,
#  'FOODS_1_051_TX_3_evaluation': 2.5041811085020852e-05,
#  'FOODS_1_051_WI_1_evaluation': 2.0591459250536746e-05,
#  'FOODS_1_051_WI_2_evaluation': 2.689838447411537e-05,
#  'FOODS_1_051_WI_3_evaluation': 1.6061947544441646e-05,
#  'FOODS_1_052_CA_1_evaluation': 7.921911275064796e-06,
#  'FOODS_1_052_CA_2_evaluation': 3.4358990830894155e-06,
#  'FOODS_1_052_CA_3_evaluation': 4.951462372099037e-06,
#  'FOODS_1_052_CA_4_evaluation': 4.86256829789625e-06,
#  'FOODS_1_052_TX_1_evaluation': 2.7908667680406897e-06,
#  'FOODS_1_052_TX_2_evaluation': 1.907542227828714e-06,
#  'FOODS_1_052_TX_3_evaluation': 3.884423885944245e-06,
#  'FOODS_1_052_WI_1_evaluation': 5.725208274979844e-06,
#  'FOODS_1_052_WI_2_evaluation': 5.538592092445126e-06,
#  'FOODS_1_052_WI_3_evaluation': 4.995359929350575e-06,
#  'FOODS_1_053_CA_1_evaluation': 8.416795309638222e-06,
#  'FOODS_1_053_CA_2_evaluation': 1.770365113009681e-05,
#  'FOODS_1_053_CA_3_evaluation': 3.2432650829235845e-05,
#  'FOODS_1_053_CA_4_evaluation': 1.8631610569369988e-05,
#  'FOODS_1_053_TX_1_evaluation': 1.3182883660186482e-05,
#  'FOODS_1_053_TX_2_evaluation': 9.267828674508317e-06,
#  'FOODS_1_053_TX_3_evaluation': 3.8342232921144704e-06,
#  'FOODS_1_053_WI_1_evaluation': 2.882428119382087e-05,
#  'FOODS_1_053_WI_2_evaluation': 1.4006725655310087e-05,
#  'FOODS_1_053_WI_3_evaluation': 2.887389319047142e-05,
#  'FOODS_1_054_CA_1_evaluation': 1.3511357662710697e-05,
#  'FOODS_1_054_CA_2_evaluation': 8.700621696811119e-06,
#  'FOODS_1_054_CA_3_evaluation': 4.140114847941679e-06,
#  'FOODS_1_054_CA_4_evaluation': 1.0382835539044453e-05,
#  'FOODS_1_054_TX_1_evaluation': 4.8180615094961255e-06,
#  'FOODS_1_054_TX_2_evaluation': 4.606754267323906e-06,
#  'FOODS_1_054_TX_3_evaluation': 6.287089396982558e-06,
#  'FOODS_1_054_WI_1_evaluation': 6.692122925022547e-06,
#  'FOODS_1_054_WI_2_evaluation': 8.302678267100463e-06,
#  'FOODS_1_054_WI_3_evaluation': 4.125494997087298e-06,
#  'FOODS_1_055_CA_1_evaluation': 1.5261970751520514e-05,
#  'FOODS_1_055_CA_2_evaluation': 1.8833842325192744e-05,
#  'FOODS_1_055_CA_3_evaluation': 3.715905806956477e-05,
#  'FOODS_1_055_CA_4_evaluation': 7.788015283139098e-06,
#  'FOODS_1_055_TX_1_evaluation': 5.464143316468106e-07,
#  'FOODS_1_055_TX_2_evaluation': 5.863409973159021e-06,
#  'FOODS_1_055_TX_3_evaluation': 1.1071750238344913e-05,
#  'FOODS_1_055_WI_1_evaluation': 1.254175509622142e-05,
#  'FOODS_1_055_WI_2_evaluation': 2.0082312610360594e-05,
#  'FOODS_1_055_WI_3_evaluation': 1.1948178603460912e-05,
#  'FOODS_1_056_CA_1_evaluation': 0.0,
#  'FOODS_1_056_CA_2_evaluation': 0.0,
#  'FOODS_1_056_CA_3_evaluation': 4.4688110423500354e-07,
#  'FOODS_1_056_CA_4_evaluation': 8.246375036098492e-07,
#  'FOODS_1_056_TX_1_evaluation': 0.0,
#  'FOODS_1_056_TX_2_evaluation': 0.0,
#  'FOODS_1_056_TX_3_evaluation': 9.292591375654969e-07,
#  'FOODS_1_056_WI_1_evaluation': 0.0,
#  'FOODS_1_056_WI_2_evaluation': 0.0,
#  'FOODS_1_056_WI_3_evaluation': 0.0,
#  'FOODS_1_057_CA_1_evaluation': 0.0,
#  'FOODS_1_057_CA_2_evaluation': 0.0,
#  'FOODS_1_057_CA_3_evaluation': 4.343858880035382e-07,
#  'FOODS_1_057_CA_4_evaluation': 0.0,
#  'FOODS_1_057_TX_1_evaluation': 0.0,
#  'FOODS_1_057_TX_2_evaluation': 0.0,
#  'FOODS_1_057_TX_3_evaluation': 0.0,
#  'FOODS_1_057_WI_1_evaluation': 0.0,
#  'FOODS_1_057_WI_2_evaluation': 0.0,
#  'FOODS_1_057_WI_3_evaluation': 8.29249135367038e-07,
#  'FOODS_1_058_CA_1_evaluation': 0.0,
#  'FOODS_1_058_CA_2_evaluation': 1.5771511946821648e-07,
#  'FOODS_1_058_CA_3_evaluation': 0.0,
#  'FOODS_1_058_CA_4_evaluation': 0.0,
#  'FOODS_1_058_TX_1_evaluation': 0.0,
#  'FOODS_1_058_TX_2_evaluation': 0.0,
#  'FOODS_1_058_TX_3_evaluation': 0.0,
#  'FOODS_1_058_WI_1_evaluation': 0.0,
#  'FOODS_1_058_WI_2_evaluation': 0.0,
#  'FOODS_1_058_WI_3_evaluation': 0.0,
#  'FOODS_1_059_CA_1_evaluation': 2.1094186463371478e-05,
#  'FOODS_1_059_CA_2_evaluation': 4.6597301678637096e-05,
#  'FOODS_1_059_CA_3_evaluation': 2.925635280633913e-05,
#  'FOODS_1_059_CA_4_evaluation': 2.8685519523615606e-05,
#  'FOODS_1_059_TX_1_evaluation': 3.430786184387337e-05,
#  'FOODS_1_059_TX_2_evaluation': 3.8669066518154034e-05,
#  'FOODS_1_059_TX_3_evaluation': 3.2263750610995064e-05,
#  'FOODS_1_059_WI_1_evaluation': 2.5962464745124146e-05,
#  'FOODS_1_059_WI_2_evaluation': 5.45040819388796e-06,
#  'FOODS_1_059_WI_3_evaluation': 7.042031358119924e-06,
#  'FOODS_1_060_CA_1_evaluation': 6.686872542508208e-06,
#  'FOODS_1_060_CA_2_evaluation': 2.9322082970621887e-06,
#  'FOODS_1_060_CA_3_evaluation': 6.523110176247603e-06,
#  'FOODS_1_060_CA_4_evaluation': 2.241385553788642e-06,
#  'FOODS_1_060_TX_1_evaluation': 0.0,
#  'FOODS_1_060_TX_2_evaluation': 9.743405357174413e-07,
#  'FOODS_1_060_TX_3_evaluation': 5.742091135897731e-07,
#  'FOODS_1_060_WI_1_evaluation': 3.82402020999572e-06,
#  'FOODS_1_060_WI_2_evaluation': 9.769039743942142e-06,
#  'FOODS_1_060_WI_3_evaluation': 6.883828117242623e-06,
#  'FOODS_1_061_CA_1_evaluation': 1.6220869259450072e-05,
#  'FOODS_1_061_CA_2_evaluation': 1.3721659805537624e-05,
#  'FOODS_1_061_CA_3_evaluation': 1.496676650629405e-05,
#  'FOODS_1_061_CA_4_evaluation': 1.5324354035106117e-05,
#  'FOODS_1_061_TX_1_evaluation': 1.2699190126262044e-05,
#  'FOODS_1_061_TX_2_evaluation': 5.251146894337469e-06,
#  'FOODS_1_061_TX_3_evaluation': 1.4344077356080178e-05,
#  'FOODS_1_061_WI_1_evaluation': 9.69893253621082e-06,
#  'FOODS_1_061_WI_2_evaluation': 1.6619103840855238e-05,
#  'FOODS_1_061_WI_3_evaluation': 8.686280665149417e-06,
#  'FOODS_1_062_CA_1_evaluation': 2.319272105940849e-05,
#  'FOODS_1_062_CA_2_evaluation': 1.774825917018576e-05,
#  'FOODS_1_062_CA_3_evaluation': 9.547437059291778e-06,
#  'FOODS_1_062_CA_4_evaluation': 1.4896605438283003e-05,
#  'FOODS_1_062_TX_1_evaluation': 6.1213822386133794e-06,
#  'FOODS_1_062_TX_2_evaluation': 9.99827585756884e-06,
#  'FOODS_1_062_TX_3_evaluation': 7.260659361434638e-06,
#  'FOODS_1_062_WI_1_evaluation': 2.8093845864982854e-05,
#  'FOODS_1_062_WI_2_evaluation': 2.2845709884446956e-06,
#  'FOODS_1_062_WI_3_evaluation': 1.1175872444170331e-05,
#  'FOODS_1_063_CA_1_evaluation': 1.0862504130300573e-05,
#  'FOODS_1_063_CA_2_evaluation': 7.192287744948322e-06,
#  'FOODS_1_063_CA_3_evaluation': 1.352918614360245e-05,
#  'FOODS_1_063_CA_4_evaluation': 9.349322163826777e-06,
#  'FOODS_1_063_TX_1_evaluation': 1.1178570983486096e-05,
#  'FOODS_1_063_TX_2_evaluation': 6.466546721764725e-06,
#  'FOODS_1_063_TX_3_evaluation': 5.4764904524427124e-06,
#  'FOODS_1_063_WI_1_evaluation': 1.9160940637694607e-05,
#  'FOODS_1_063_WI_2_evaluation': 1.5961223644064702e-05,
#  'FOODS_1_063_WI_3_evaluation': 7.078487519916171e-06,
#  'FOODS_1_064_CA_1_evaluation': 9.966982145348006e-06,
#  'FOODS_1_064_CA_2_evaluation': 1.0769822148542277e-05,
#  'FOODS_1_064_CA_3_evaluation': 1.0871902237081827e-05,
#  'FOODS_1_064_CA_4_evaluation': 1.2506403403465455e-05,
#  'FOODS_1_064_TX_1_evaluation': 6.826104779187604e-06,
#  'FOODS_1_064_TX_2_evaluation': 2.2838740718478918e-06,
#  'FOODS_1_064_TX_3_evaluation': 3.880465653840959e-06,
#  'FOODS_1_064_WI_1_evaluation': 6.94673697677296e-06,
#  'FOODS_1_064_WI_2_evaluation': 4.934868904558539e-06,
#  'FOODS_1_064_WI_3_evaluation': 4.737633325112433e-06,
#  'FOODS_1_065_CA_1_evaluation': 1.1822817990436887e-05,
#  'FOODS_1_065_CA_2_evaluation': 2.4612437473506372e-05,
#  'FOODS_1_065_CA_3_evaluation': 1.1208257436254912e-05,
#  'FOODS_1_065_CA_4_evaluation': 1.636480657677027e-05,
#  'FOODS_1_065_TX_1_evaluation': 8.92115691632934e-06,
#  'FOODS_1_065_TX_2_evaluation': 1.4007162906856568e-05,
#  'FOODS_1_065_TX_3_evaluation': 1.961684424860059e-06,
#  'FOODS_1_065_WI_1_evaluation': 1.9951694700947564e-05,
#  'FOODS_1_065_WI_2_evaluation': 5.869462270921176e-06,
#  'FOODS_1_065_WI_3_evaluation': 1.9312690204307774e-05,
#  'FOODS_1_066_CA_1_evaluation': 5.0496553216951855e-06,
#  'FOODS_1_066_CA_2_evaluation': 4.9505172663220504e-06,
#  'FOODS_1_066_CA_3_evaluation': 4.205141566643418e-06,
#  'FOODS_1_066_CA_4_evaluation': 3.1656627053219083e-06,
#  'FOODS_1_066_TX_1_evaluation': 2.0525271363059093e-06,
#  'FOODS_1_066_TX_2_evaluation': 1.3932965190908755e-06,
#  'FOODS_1_066_TX_3_evaluation': 4.393957802963436e-06,
#  'FOODS_1_066_WI_1_evaluation': 8.937781359602136e-06,
#  'FOODS_1_066_WI_2_evaluation': 4.409220069071924e-06,
#  'FOODS_1_066_WI_3_evaluation': 4.9987331123389495e-06,
#  'FOODS_1_067_CA_1_evaluation': 8.351822125773739e-06,
#  'FOODS_1_067_CA_2_evaluation': 9.736070373016755e-06,
#  'FOODS_1_067_CA_3_evaluation': 8.66105554146212e-06,
#  'FOODS_1_067_CA_4_evaluation': 1.055545691562527e-05,
#  'FOODS_1_067_TX_1_evaluation': 5.514987341806138e-06,
#  'FOODS_1_067_TX_2_evaluation': 5.686425467699467e-06,
#  'FOODS_1_067_TX_3_evaluation': 9.553460654539216e-06,
#  'FOODS_1_067_WI_1_evaluation': 7.318186815979968e-06,
#  'FOODS_1_067_WI_2_evaluation': 8.459262744619843e-06,
#  'FOODS_1_067_WI_3_evaluation': 7.17552873079929e-06,
#  'FOODS_1_068_CA_1_evaluation': 1.2593091017878036e-06,
#  'FOODS_1_068_CA_2_evaluation': 1.3810255638809143e-05,
#  'FOODS_1_068_CA_3_evaluation': 7.266451225244836e-06,
#  'FOODS_1_068_CA_4_evaluation': 2.7207942066795506e-05,
#  'FOODS_1_068_TX_1_evaluation': 0.0,
#  'FOODS_1_068_TX_2_evaluation': 1.071892876441001e-06,
#  'FOODS_1_068_TX_3_evaluation': 1.0258129056284026e-06,
#  'FOODS_1_068_WI_1_evaluation': 1.5871410385448105e-06,
#  'FOODS_1_068_WI_2_evaluation': 3.4576852312874333e-06,
#  'FOODS_1_068_WI_3_evaluation': 2.131198484459272e-06,
#  'FOODS_1_069_CA_1_evaluation': 1.420284432627031e-05,
#  'FOODS_1_069_CA_2_evaluation': 1.9906277486800643e-05,
#  'FOODS_1_069_CA_3_evaluation': 1.8387851499944595e-05,
#  'FOODS_1_069_CA_4_evaluation': 2.0188010552656273e-05,
#  'FOODS_1_069_TX_1_evaluation': 9.161249246421151e-06,
#  'FOODS_1_069_TX_2_evaluation': 1.0416227278641636e-05,
#  'FOODS_1_069_TX_3_evaluation': 8.148819472829303e-06,
#  'FOODS_1_069_WI_1_evaluation': 1.5445135771264134e-05,
#  'FOODS_1_069_WI_2_evaluation': 4.0446841701477915e-06,
#  'FOODS_1_069_WI_3_evaluation': 1.328891027566387e-05,
#  'FOODS_1_070_CA_1_evaluation': 2.4297078631026113e-06,
#  'FOODS_1_070_CA_2_evaluation': 4.80917787610809e-06,
#  'FOODS_1_070_CA_3_evaluation': 2.123638740736802e-06,
#  'FOODS_1_070_CA_4_evaluation': 3.765853116116786e-06,
#  'FOODS_1_070_TX_1_evaluation': 1.5786512274181732e-06,
#  'FOODS_1_070_TX_2_evaluation': 1.2864151897530873e-06,
#  'FOODS_1_070_TX_3_evaluation': 4.269638046669056e-06,
#  'FOODS_1_070_WI_1_evaluation': 4.829095942135273e-06,
#  'FOODS_1_070_WI_2_evaluation': 4.992873821835794e-06,
#  'FOODS_1_070_WI_3_evaluation': 2.955985925880735e-06,
#  'FOODS_1_071_CA_1_evaluation': 8.33179319503641e-06,
#  'FOODS_1_071_CA_2_evaluation': 1.069564048473703e-05,
#  'FOODS_1_071_CA_3_evaluation': 7.3551081105003535e-06,
#  'FOODS_1_071_CA_4_evaluation': 1.1284481393502618e-05,
#  'FOODS_1_071_TX_1_evaluation': 3.92052797105775e-06,
#  'FOODS_1_071_TX_2_evaluation': 0.0,
#  'FOODS_1_071_TX_3_evaluation': 0.0,
#  'FOODS_1_071_WI_1_evaluation': 8.725853767353524e-06,
#  'FOODS_1_071_WI_2_evaluation': 1.6811519975210488e-05,
#  'FOODS_1_071_WI_3_evaluation': 1.745738853978754e-05,
#  'FOODS_1_072_CA_1_evaluation': 3.779281775162739e-06,
#  'FOODS_1_072_CA_2_evaluation': 6.962128834283826e-05,
#  'FOODS_1_072_CA_3_evaluation': 3.9392625193484356e-05,
#  'FOODS_1_072_CA_4_evaluation': 7.508186562673485e-05,
#  'FOODS_1_072_TX_1_evaluation': 1.6914398873466694e-05,
#  'FOODS_1_072_TX_2_evaluation': 1.6063593080558414e-05,
#  'FOODS_1_072_TX_3_evaluation': 2.3568885480067157e-05,
#  'FOODS_1_072_WI_1_evaluation': 2.4045999475108878e-05,
#  'FOODS_1_072_WI_2_evaluation': 1.770274922965095e-05,
#  'FOODS_1_072_WI_3_evaluation': 1.6588209656296533e-05,
#  'FOODS_1_073_CA_1_evaluation': 7.77053341361275e-06,
#  'FOODS_1_073_CA_2_evaluation': 6.528918747372672e-06,
#  'FOODS_1_073_CA_3_evaluation': 6.996430873254614e-06,
#  'FOODS_1_073_CA_4_evaluation': 5.591217240189614e-06,
#  'FOODS_1_073_TX_1_evaluation': 1.1389986675264443e-06,
#  'FOODS_1_073_TX_2_evaluation': 4.596411233705204e-06,
#  'FOODS_1_073_TX_3_evaluation': 5.957979651701016e-06,
#  'FOODS_1_073_WI_1_evaluation': 7.2879812864596005e-06,
#  'FOODS_1_073_WI_2_evaluation': 9.464859111014363e-06,
#  'FOODS_1_073_WI_3_evaluation': 8.131063641419502e-06,
#  'FOODS_1_074_CA_1_evaluation': 1.2722859159114107e-05,
#  'FOODS_1_074_CA_2_evaluation': 1.1540162525033565e-05,
#  'FOODS_1_074_CA_3_evaluation': 1.31908069057701e-05,
#  'FOODS_1_074_CA_4_evaluation': 8.24652752778782e-06,
#  'FOODS_1_074_TX_1_evaluation': 0.0,
#  'FOODS_1_074_TX_2_evaluation': 6.1822953649762315e-06,
#  'FOODS_1_074_TX_3_evaluation': 5.36519273859582e-06,
#  'FOODS_1_074_WI_1_evaluation': 1.3613080382900518e-05,
#  'FOODS_1_074_WI_2_evaluation': 7.72124550550603e-06,
#  'FOODS_1_074_WI_3_evaluation': 7.050601641663231e-06,
#  'FOODS_1_075_CA_1_evaluation': 1.4878824602641864e-05,
#  'FOODS_1_075_CA_2_evaluation': 7.811229367714262e-06,
#  'FOODS_1_075_CA_3_evaluation': 1.0950693137949562e-05,
#  'FOODS_1_075_CA_4_evaluation': 7.133507134937047e-06,
#  'FOODS_1_075_TX_1_evaluation': 2.4236505200884093e-06,
#  'FOODS_1_075_TX_2_evaluation': 4.76704562987533e-06,
#  'FOODS_1_075_TX_3_evaluation': 1.9881475243816486e-06,
#  'FOODS_1_075_WI_1_evaluation': 1.18444620955355e-05,
#  'FOODS_1_075_WI_2_evaluation': 6.229780212695287e-06,
#  'FOODS_1_075_WI_3_evaluation': 4.715694742527815e-06,
#  'FOODS_1_076_CA_1_evaluation': 4.939853989546464e-05,
#  'FOODS_1_076_CA_2_evaluation': 2.743826597610952e-05,
#  'FOODS_1_076_CA_3_evaluation': 3.116695629602836e-05,
#  'FOODS_1_076_CA_4_evaluation': 2.4429997497076474e-05,
#  'FOODS_1_076_TX_1_evaluation': 6.289588423305033e-05,
#  'FOODS_1_076_TX_2_evaluation': 2.5881431333919538e-05,
#  'FOODS_1_076_TX_3_evaluation': 4.925370197689068e-05,
#  'FOODS_1_076_WI_1_evaluation': 3.1654556142868e-05,
#  'FOODS_1_076_WI_2_evaluation': 2.7504997964299292e-05,
#  'FOODS_1_076_WI_3_evaluation': 1.9585954598468418e-05,
#  'FOODS_1_077_CA_1_evaluation': 5.764375326990094e-06,
#  'FOODS_1_077_CA_2_evaluation': 9.690872281059807e-06,
#  'FOODS_1_077_CA_3_evaluation': 1.171024521184182e-05,
#  'FOODS_1_077_CA_4_evaluation': 0.0,
#  'FOODS_1_077_TX_1_evaluation': 4.630935994764428e-06,
#  'FOODS_1_077_TX_2_evaluation': 2.054945635094644e-05,
#  'FOODS_1_077_TX_3_evaluation': 3.630350534438957e-06,
#  'FOODS_1_077_WI_1_evaluation': 1.2270811049921674e-05,
#  'FOODS_1_077_WI_2_evaluation': 1.016632488788342e-05,
#  'FOODS_1_077_WI_3_evaluation': 1.045064819272607e-06,
#  'FOODS_1_078_CA_1_evaluation': 1.7782084895048467e-05,
#  'FOODS_1_078_CA_2_evaluation': 2.098416995838092e-05,
#  'FOODS_1_078_CA_3_evaluation': 1.4477276761087201e-05,
#  'FOODS_1_078_CA_4_evaluation': 8.601458741208023e-06,
#  'FOODS_1_078_TX_1_evaluation': 2.156725925085521e-06,
#  'FOODS_1_078_TX_2_evaluation': 8.580460439663326e-06,
#  'FOODS_1_078_TX_3_evaluation': 9.50481081120342e-06,
#  'FOODS_1_078_WI_1_evaluation': 5.005075811717048e-06,
#  'FOODS_1_078_WI_2_evaluation': 1.788302775599058e-05,
#  'FOODS_1_078_WI_3_evaluation': 1.791049550790204e-05,
#  'FOODS_1_079_CA_1_evaluation': 0.0,
#  'FOODS_1_079_CA_2_evaluation': 0.0,
#  'FOODS_1_079_CA_3_evaluation': 4.188222450771873e-06,
#  'FOODS_1_079_CA_4_evaluation': 5.737941780044259e-06,
#  'FOODS_1_079_TX_1_evaluation': 2.1466545636839183e-06,
#  'FOODS_1_079_TX_2_evaluation': 1.6644298011816246e-05,
#  'FOODS_1_079_TX_3_evaluation': 1.904176411537984e-05,
#  'FOODS_1_079_WI_1_evaluation': 1.4566133188878304e-05,
#  'FOODS_1_079_WI_2_evaluation': 1.67538053655632e-05,
#  'FOODS_1_079_WI_3_evaluation': 1.2527249437121009e-06,
#  'FOODS_1_080_CA_1_evaluation': 3.090126915854244e-05,
#  'FOODS_1_080_CA_2_evaluation': 5.217989867071075e-05,
#  'FOODS_1_080_CA_3_evaluation': 3.520951484123264e-05,
#  'FOODS_1_080_CA_4_evaluation': 3.776624766698072e-05,
#  'FOODS_1_080_TX_1_evaluation': 4.673859908095207e-05,
#  'FOODS_1_080_TX_2_evaluation': 1.8310040405053556e-05,
#  'FOODS_1_080_TX_3_evaluation': 1.0488635551979898e-05,
#  'FOODS_1_080_WI_1_evaluation': 3.8064594116010275e-05,
#  'FOODS_1_080_WI_2_evaluation': 2.8263637545076702e-05,
#  'FOODS_1_080_WI_3_evaluation': 1.4590537873086364e-05,
#  'FOODS_1_081_CA_1_evaluation': 1.9329542015933862e-05,
#  'FOODS_1_081_CA_2_evaluation': 4.215595257363143e-05,
#  'FOODS_1_081_CA_3_evaluation': 1.9911800326901742e-05,
#  'FOODS_1_081_CA_4_evaluation': 1.5849710775968275e-05,
#  'FOODS_1_081_TX_1_evaluation': 1.4198763434288103e-05,
#  'FOODS_1_081_TX_2_evaluation': 1.6838945367877548e-05,
#  'FOODS_1_081_TX_3_evaluation': 1.631001665709317e-05,
#  'FOODS_1_081_WI_1_evaluation': 2.5702186234885317e-05,
#  'FOODS_1_081_WI_2_evaluation': 0.0,
#  'FOODS_1_081_WI_3_evaluation': 2.3089960904545723e-05,
#  'FOODS_1_082_CA_1_evaluation': 1.3826339099724255e-05,
#  'FOODS_1_082_CA_2_evaluation': 1.2814512074177396e-05,
#  'FOODS_1_082_CA_3_evaluation': 3.832214016025055e-06,
#  'FOODS_1_082_CA_4_evaluation': 8.688653008172047e-06,
#  'FOODS_1_082_TX_1_evaluation': 0.0,
#  'FOODS_1_082_TX_2_evaluation': 3.5217589480686487e-06,
#  'FOODS_1_082_TX_3_evaluation': 3.688450778178526e-06,
#  'FOODS_1_082_WI_1_evaluation': 6.596541037372641e-06,
#  'FOODS_1_082_WI_2_evaluation': 1.1364241984435645e-05,
#  'FOODS_1_082_WI_3_evaluation': 8.659334070666373e-06,
#  'FOODS_1_083_CA_1_evaluation': 5.581209947053143e-06,
#  'FOODS_1_083_CA_2_evaluation': 1.2543286275580374e-05,
#  'FOODS_1_083_CA_3_evaluation': 8.986945574998769e-06,
#  'FOODS_1_083_CA_4_evaluation': 6.988452020423309e-06,
#  'FOODS_1_083_TX_1_evaluation': 2.599483274865167e-06,
#  'FOODS_1_083_TX_2_evaluation': 3.3764146187754323e-06,
#  'FOODS_1_083_TX_3_evaluation': 0.0,
#  'FOODS_1_083_WI_1_evaluation': 5.413265058288313e-06,
#  'FOODS_1_083_WI_2_evaluation': 1.1334473916638143e-05,
#  'FOODS_1_083_WI_3_evaluation': 7.631643999564637e-06,
#  'FOODS_1_084_CA_1_evaluation': 0.0,
#  'FOODS_1_084_CA_2_evaluation': 2.5106580419268258e-05,
#  'FOODS_1_084_CA_3_evaluation': 3.6602707646363595e-06,
#  'FOODS_1_084_CA_4_evaluation': 6.777701249250026e-06,
#  'FOODS_1_084_TX_1_evaluation': 4.004372165248925e-05,
#  'FOODS_1_084_TX_2_evaluation': 2.752292080407037e-05,
#  'FOODS_1_084_TX_3_evaluation': 2.8254162250511526e-05,
#  'FOODS_1_084_WI_1_evaluation': 5.197646735853897e-05,
#  'FOODS_1_084_WI_2_evaluation': 8.386421135116279e-06,
#  'FOODS_1_084_WI_3_evaluation': 2.7997066656131047e-05,
#  'FOODS_1_085_CA_1_evaluation': 8.633064946775661e-06,
#  'FOODS_1_085_CA_2_evaluation': 1.0767234097857038e-05,
#  'FOODS_1_085_CA_3_evaluation': 7.4917545212577365e-06,
#  'FOODS_1_085_CA_4_evaluation': 8.547666879534255e-06,
#  'FOODS_1_085_TX_1_evaluation': 6.283789878752291e-06,
#  'FOODS_1_085_TX_2_evaluation': 6.806478591224182e-06,
#  'FOODS_1_085_TX_3_evaluation': 1.5567139980157404e-05,
#  'FOODS_1_085_WI_1_evaluation': 1.2129734367462725e-05,
#  'FOODS_1_085_WI_2_evaluation': 1.240590008138551e-05,
#  'FOODS_1_085_WI_3_evaluation': 9.951393446282422e-06,
#  'FOODS_1_086_CA_1_evaluation': 1.2638251426824967e-05,
#  'FOODS_1_086_CA_2_evaluation': 8.117617460508205e-06,
#  'FOODS_1_086_CA_3_evaluation': 8.772221312895805e-06,
#  'FOODS_1_086_CA_4_evaluation': 1.043044423717043e-05,
#  'FOODS_1_086_TX_1_evaluation': 3.1694643213585067e-06,
#  'FOODS_1_086_TX_2_evaluation': 2.884212686556771e-06,
#  'FOODS_1_086_TX_3_evaluation': 9.043885397292812e-06,
#  'FOODS_1_086_WI_1_evaluation': 1.0102264923350312e-05,
#  'FOODS_1_086_WI_2_evaluation': 1.5454078948120727e-05,
#  'FOODS_1_086_WI_3_evaluation': 9.147137047232873e-06,
#  'FOODS_1_087_CA_1_evaluation': 5.229888863065364e-05,
#  'FOODS_1_087_CA_2_evaluation': 4.427172103269094e-05,
#  'FOODS_1_087_CA_3_evaluation': 5.139657690216809e-05,
#  'FOODS_1_087_CA_4_evaluation': 2.4636468009831026e-05,
#  'FOODS_1_087_TX_1_evaluation': 4.36098260159456e-05,
#  'FOODS_1_087_TX_2_evaluation': 5.51311962749057e-05,
#  'FOODS_1_087_TX_3_evaluation': 4.301591924743603e-05,
#  'FOODS_1_087_WI_1_evaluation': 3.884123649892399e-05,
#  'FOODS_1_087_WI_2_evaluation': 2.275071125507171e-05,
#  'FOODS_1_087_WI_3_evaluation': 4.0516285344343094e-05,
#  'FOODS_1_088_CA_1_evaluation': 1.8536754746593494e-05,
#  'FOODS_1_088_CA_2_evaluation': 3.904088731356221e-05,
#  'FOODS_1_088_CA_3_evaluation': 4.2292151506183034e-05,
#  'FOODS_1_088_CA_4_evaluation': 1.7557116981301878e-05,
#  'FOODS_1_088_TX_1_evaluation': 1.0860394537668575e-05,
#  'FOODS_1_088_TX_2_evaluation': 1.637909667318596e-05,
#  'FOODS_1_088_TX_3_evaluation': 1.7114987276241153e-05,
#  'FOODS_1_088_WI_1_evaluation': 2.2519620247840443e-05,
#  'FOODS_1_088_WI_2_evaluation': 1.4978085761302898e-05,
#  'FOODS_1_088_WI_3_evaluation': 1.6444523653323286e-05,
#  'FOODS_1_089_CA_1_evaluation': 1.1960839150411082e-05,
#  'FOODS_1_089_CA_2_evaluation': 1.7473362567691555e-05,
#  'FOODS_1_089_CA_3_evaluation': 2.4222739913256413e-05,
#  'FOODS_1_089_CA_4_evaluation': 2.3755071892939686e-05,
#  'FOODS_1_089_TX_1_evaluation': 3.519824628622545e-06,
#  'FOODS_1_089_TX_2_evaluation': 5.995758976871268e-06,
#  'FOODS_1_089_TX_3_evaluation': 7.918642661404158e-06,
#  'FOODS_1_089_WI_1_evaluation': 1.4912433221762579e-05,
#  'FOODS_1_089_WI_2_evaluation': 1.610212516606995e-05,
#  'FOODS_1_089_WI_3_evaluation': 7.65803303977279e-06,
#  'FOODS_1_090_CA_1_evaluation': 9.681133250945242e-06,
#  'FOODS_1_090_CA_2_evaluation': 3.1258721214027225e-05,
#  'FOODS_1_090_CA_3_evaluation': 1.611656542778506e-05,
#  'FOODS_1_090_CA_4_evaluation': 1.776200538258019e-05,
#  'FOODS_1_090_TX_1_evaluation': 3.54669308167868e-06,
#  'FOODS_1_090_TX_2_evaluation': 6.710294688762237e-06,
#  'FOODS_1_090_TX_3_evaluation': 3.6992198494574812e-06,
#  'FOODS_1_090_WI_1_evaluation': 1.7294201435021347e-05,
#  'FOODS_1_090_WI_2_evaluation': 2.0021017291604696e-05,
#  'FOODS_1_090_WI_3_evaluation': 1.0263659325918462e-05,
#  'FOODS_1_091_CA_1_evaluation': 0.0,
#  'FOODS_1_091_CA_2_evaluation': 0.0,
#  'FOODS_1_091_CA_3_evaluation': 0.0,
#  'FOODS_1_091_CA_4_evaluation': 0.0,
#  'FOODS_1_091_TX_1_evaluation': 0.0,
#  'FOODS_1_091_TX_2_evaluation': 0.0,
#  'FOODS_1_091_TX_3_evaluation': 0.0,
#  'FOODS_1_091_WI_1_evaluation': 0.0,
#  'FOODS_1_091_WI_2_evaluation': 0.0,
#  'FOODS_1_091_WI_3_evaluation': 4.1919713564986065e-07,
#  'FOODS_1_092_CA_1_evaluation': 7.835364864533821e-06,
#  'FOODS_1_092_CA_2_evaluation': 1.1027268429244831e-05,
#  'FOODS_1_092_CA_3_evaluation': 3.918798070384386e-06,
#  'FOODS_1_092_CA_4_evaluation': 1.5521260047534958e-05,
#  'FOODS_1_092_TX_1_evaluation': 1.8798339633059869e-06,
#  'FOODS_1_092_TX_2_evaluation': 5.221251003479175e-06,
#  'FOODS_1_092_TX_3_evaluation': 5.425364891638693e-06,
#  'FOODS_1_092_WI_1_evaluation': 5.968242043609633e-06,
#  'FOODS_1_092_WI_2_evaluation': 7.187855270851703e-06,
#  'FOODS_1_092_WI_3_evaluation': 6.557166930118222e-06,
#  'FOODS_1_093_CA_1_evaluation': 1.609755098211801e-05,
#  'FOODS_1_093_CA_2_evaluation': 4.526608742829259e-05,
#  'FOODS_1_093_CA_3_evaluation': 3.072594594350275e-05,
#  'FOODS_1_093_CA_4_evaluation': 9.302319412372345e-06,
#  'FOODS_1_093_TX_1_evaluation': 5.455887296217148e-06,
#  'FOODS_1_093_TX_2_evaluation': 2.0418594775545215e-05,
#  'FOODS_1_093_TX_3_evaluation': 6.564429930260486e-06,
#  'FOODS_1_093_WI_1_evaluation': 1.7970351576014967e-05,
#  'FOODS_1_093_WI_2_evaluation': 9.797389239861918e-06,
#  'FOODS_1_093_WI_3_evaluation': 1.8896400145874138e-05,
#  'FOODS_1_094_CA_1_evaluation': 1.095736534203898e-05,
#  'FOODS_1_094_CA_2_evaluation': 2.9292131199583075e-05,
#  'FOODS_1_094_CA_3_evaluation': 2.440658397602634e-05,
#  'FOODS_1_094_CA_4_evaluation': 1.22722093402614e-05,
#  'FOODS_1_094_TX_1_evaluation': 0.0,
#  'FOODS_1_094_TX_2_evaluation': 1.5998368495877477e-05,
#  'FOODS_1_094_TX_3_evaluation': 5.279232184818586e-06,
#  'FOODS_1_094_WI_1_evaluation': 1.6281158169882623e-05,
#  'FOODS_1_094_WI_2_evaluation': 1.7472095026695827e-05,
#  'FOODS_1_094_WI_3_evaluation': 9.265077968087451e-06,
#  'FOODS_1_095_CA_1_evaluation': 1.776697436509497e-06,
#  'FOODS_1_095_CA_2_evaluation': 4.992249508589724e-06,
#  'FOODS_1_095_CA_3_evaluation': 3.6360443821331666e-06,
#  'FOODS_1_095_CA_4_evaluation': 0.0,
#  'FOODS_1_095_TX_1_evaluation': 1.2092991122098857e-05,
#  'FOODS_1_095_TX_2_evaluation': 7.940474286750233e-06,
#  'FOODS_1_095_TX_3_evaluation': 3.0942104594395336e-05,
#  'FOODS_1_095_WI_1_evaluation': 2.639770409514525e-06,
#  'FOODS_1_095_WI_2_evaluation': 1.1345411297794573e-05,
#  'FOODS_1_095_WI_3_evaluation': 1.7081209821364003e-06,
#  'FOODS_1_096_CA_1_evaluation': 2.967240087845815e-05,
#  'FOODS_1_096_CA_2_evaluation': 6.143955277338966e-05,
#  'FOODS_1_096_CA_3_evaluation': 4.972842626876145e-05,
#  'FOODS_1_096_CA_4_evaluation': 2.792055974755977e-05,
#  'FOODS_1_096_TX_1_evaluation': 9.753987593840498e-05,
#  'FOODS_1_096_TX_2_evaluation': 7.799539630202519e-05,
#  'FOODS_1_096_TX_3_evaluation': 0.00013406864423074565,
#  'FOODS_1_096_WI_1_evaluation': 0.00016758910628016937,
#  'FOODS_1_096_WI_2_evaluation': 0.00031135279986173895,
#  'FOODS_1_096_WI_3_evaluation': 0.00019622644048666236,
#  'FOODS_1_097_CA_1_evaluation': 5.596785920670764e-06,
#  'FOODS_1_097_CA_2_evaluation': 3.622383705088013e-06,
#  'FOODS_1_097_CA_3_evaluation': 3.1151901011008298e-06,
#  'FOODS_1_097_CA_4_evaluation': 4.308966887350005e-06,
#  'FOODS_1_097_TX_1_evaluation': 8.972656893687902e-06,
#  'FOODS_1_097_TX_2_evaluation': 5.376881102510672e-06,
#  'FOODS_1_097_TX_3_evaluation': 7.466924512321915e-06,
#  'FOODS_1_097_WI_1_evaluation': 4.345058232467705e-06,
#  'FOODS_1_097_WI_2_evaluation': 7.872820704196052e-06,
#  'FOODS_1_097_WI_3_evaluation': 6.51592466525996e-06,
#  'FOODS_1_098_CA_1_evaluation': 9.183602675247578e-06,
#  'FOODS_1_098_CA_2_evaluation': 5.677314313401501e-06,
#  'FOODS_1_098_CA_3_evaluation': 1.5470882398270554e-05,
#  'FOODS_1_098_CA_4_evaluation': 1.314664726077236e-05,
#  'FOODS_1_098_TX_1_evaluation': 4.470616263486427e-05,
#  'FOODS_1_098_TX_2_evaluation': 1.96107593260675e-05,
#  'FOODS_1_098_TX_3_evaluation': 5.297545860648461e-05,
#  'FOODS_1_098_WI_1_evaluation': 4.53225622406515e-05,
#  'FOODS_1_098_WI_2_evaluation': 5.4780774650064026e-05,
#  'FOODS_1_098_WI_3_evaluation': 4.5863677600823634e-05,
#  'FOODS_1_099_CA_1_evaluation': 7.484607303637004e-06,
#  'FOODS_1_099_CA_2_evaluation': 1.0955756149100918e-05,
#  'FOODS_1_099_CA_3_evaluation': 1.0409275541798533e-05,
#  'FOODS_1_099_CA_4_evaluation': 7.86618570835132e-06,
#  'FOODS_1_099_TX_1_evaluation': 1.1535354120521827e-05,
#  'FOODS_1_099_TX_2_evaluation': 9.208449293887087e-06,
#  'FOODS_1_099_TX_3_evaluation': 1.1544481122336624e-05,
#  'FOODS_1_099_WI_1_evaluation': 4.610857768318331e-06,
#  'FOODS_1_099_WI_2_evaluation': 4.205910976302058e-06,
#  'FOODS_1_099_WI_3_evaluation': 5.9394297760545666e-06,
#  'FOODS_1_101_CA_1_evaluation': 0.0,
#  'FOODS_1_101_CA_2_evaluation': 9.204979512678785e-06,
#  'FOODS_1_101_CA_3_evaluation': 5.1752700718869305e-06,
#  'FOODS_1_101_CA_4_evaluation': 8.438796818430361e-06,
#  'FOODS_1_101_TX_1_evaluation': 4.025190878543951e-06,
#  'FOODS_1_101_TX_2_evaluation': 0.0,
#  'FOODS_1_101_TX_3_evaluation': 2.751009103432178e-06,
#  'FOODS_1_101_WI_1_evaluation': 9.182437510974357e-06,
#  'FOODS_1_101_WI_2_evaluation': 1.3528755353570746e-05,
#  'FOODS_1_101_WI_3_evaluation': 7.73038976518832e-06,
#  'FOODS_1_102_CA_1_evaluation': 4.4329771589385634e-06,
#  'FOODS_1_102_CA_2_evaluation': 8.297710122420248e-06,
#  'FOODS_1_102_CA_3_evaluation': 7.735427485555697e-06,
#  'FOODS_1_102_CA_4_evaluation': 1.9459393779444717e-06,
#  'FOODS_1_102_TX_1_evaluation': 1.0779812022621556e-05,
#  'FOODS_1_102_TX_2_evaluation': 7.480114698045223e-06,
#  'FOODS_1_102_TX_3_evaluation': 7.996696317018374e-06,
#  'FOODS_1_102_WI_1_evaluation': 1.0807680975132293e-05,
#  'FOODS_1_102_WI_2_evaluation': 9.055167829704016e-06,
#  'FOODS_1_102_WI_3_evaluation': 1.0502034701589797e-05,
#  ...}

# %%
lgb_params = {
    #"boosting_type": "goss",
    "n_estimators": 1000,
    "boosting_type": "gbdt",
    "objective": "tweedie",
    "tweedie_variance_power": 1.1,
    "metric": "rmse",
    "learning_rate": 0.01,
    #"num_leaves": 2 ** 5 - 1,
    #"min_data_in_leaf": 2 ** 12 - 1,
    "feature_fraction": 0.5,
    #"max_bin": 100,
    "boost_from_average": False,
    #"num_boost_round": 1400,
    "verbose": -1,
    #"num_threads": os.cpu_count(),
    "force_row_wise": True,
    "seed": 42
}

# %%
# %%time
all_subs = pd.DataFrame()
for cat_id, store_id in groups:
    print(f'cat_id: {cat_id}, store_id: {store_id}')
    feature_df = pd.read_csv(f'../data/cat_and_store_data/{cat_id}_and_{store_id}_features.csv')
    target_df = pd.read_csv(f'../data/cat_and_store_data/{cat_id}_and_{store_id}_target.csv')
    feature_df['sample_weight'] = feature_df.id.map(weight_scale_dict)
    select_train = train_data[(train_data['cat_id']==cat_id) & (train_data['store_id']==store_id)]
    
    price_cols = [col for col in feature_df.columns if 'price' in col]
    
    X_columns = feature_df.columns.drop(['id', 'sample_weight']).drop(price_cols)
    
    X = feature_df
    y = target_df
    
    #tsv = TimeSeriesSplit(n_splits=5, test_size=len(select_train)*90) 
    # 由于每个日期的商品个数可能略有不同，比如新上架商品，所以指定size切割的方式不合理，需要指定日期进行切割
    oof = pd.DataFrame()
    y_fits = pd.DataFrame()
    y_trues = pd.DataFrame()
    
    split_days = [1773, 1801, 1829, 1857, 1885]
    
    for i, split_day in enumerate(split_days):
        print(f'Fold {i}')
        X_train = X[X.trend<=split_day]
        y_train = y.iloc[:len(X_train)]
        X_valid = X[(X.trend>split_day) & (X.trend<=split_day+28)]
        y_valid = y.iloc[-len(X_valid):]

        model = LinearRegression()
        #model.fit(X_train[X_columns], y_train, sample_weight=X_train['sample_weight'].values)
        model.fit(X_train[X_columns], y_train)

        y_fit = pd.DataFrame(model.predict(X_train[X_columns]), index=X_train.index, columns=y.columns)
        y_pred = pd.DataFrame(model.predict(X_valid[X_columns]), index=X_valid.index, columns=y.columns)
        
        train_rmse = mean_squared_error(y_train, y_fit, squared=False)
        test_rmse = mean_squared_error(y_valid, y_pred, squared=False)
        print((f"Train RMSE: {train_rmse:.5f}\n" f"Test RMSE: {test_rmse:.5f}"))
        
        oof = pd.concat([y_pred, oof], axis=0)
        y_trues = pd.concat([y_valid, y_trues], axis=0)
        
    oof_rmse = mean_squared_error(y_trues, oof, squared=False)
    print(f"OOF RMSE: {oof_rmse:.5f}")
    
    pred_day = 1913
    pred_df = pd.concat([feature_df[-len(oof):].reset_index(), oof.reset_index()], axis=1)
    pred_df = pred_df[pred_df['trend']==pred_day]
    
    wrmsse_score = get_wrmsse_score(select_train.reset_index(), pred_df, pred_day)
    print(f"OOF WRMSSE: {wrmsse_score:.5f}")
# Out:
# cat_id: HOBBIES, store_id: CA_1
# Fold 0
# Train RMSE: 2.29995
# Test RMSE: 2.25151
# Fold 1
# Train RMSE: 2.30106
# Test RMSE: 2.21045
# Fold 2
# Train RMSE: 2.30075
# Test RMSE: 2.20284
# Fold 3
# Train RMSE: 2.29952
# Test RMSE: 2.19325
# Fold 4
# Train RMSE: 2.29737
# Test RMSE: 2.17543
# OOF RMSE: 2.20687
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.81962
# cat_id: HOUSEHOLD, store_id: CA_1
# Fold 0
# Train RMSE: 1.19494
# Test RMSE: 1.44074
# Fold 1
# Train RMSE: 1.19734
# Test RMSE: 1.45105
# Fold 2
# Train RMSE: 1.20009
# Test RMSE: 1.44671
# Fold 3
# Train RMSE: 1.20215
# Test RMSE: 1.42030
# Fold 4
# Train RMSE: 1.20486
# Test RMSE: 1.39921
# OOF RMSE: 1.43177
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.66203
# cat_id: FOODS, store_id: CA_1
# Fold 0
# Train RMSE: 3.33390
# Test RMSE: 3.39524
# Fold 1
# Train RMSE: 3.32626
# Test RMSE: 3.08183
# Fold 2
# Train RMSE: 3.31676
# Test RMSE: 2.96714
# Fold 3
# Train RMSE: 3.30771
# Test RMSE: 2.88187
# Fold 4
# Train RMSE: 3.30046
# Test RMSE: 2.64225
# OOF RMSE: 3.00412
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.87677
# cat_id: HOBBIES, store_id: CA_2
# Fold 0
# Train RMSE: 1.75352
# Test RMSE: 1.77367
# Fold 1
# Train RMSE: 1.75676
# Test RMSE: 1.76558
# Fold 2
# Train RMSE: 1.75742
# Test RMSE: 1.73856
# Fold 3
# Train RMSE: 1.75776
# Test RMSE: 1.72816
# Fold 4
# Train RMSE: 1.75728
# Test RMSE: 1.72488
# OOF RMSE: 1.74629
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.97637
# cat_id: HOUSEHOLD, store_id: CA_2
# Fold 0
# Train RMSE: 1.35964
# Test RMSE: 1.54191
# Fold 1
# Train RMSE: 1.36055
# Test RMSE: 1.53838
# Fold 2
# Train RMSE: 1.36083
# Test RMSE: 1.52569
# Fold 3
# Train RMSE: 1.36086
# Test RMSE: 1.53909
# Fold 4
# Train RMSE: 1.36238
# Test RMSE: 1.49084
# OOF RMSE: 1.52739
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.82401
# cat_id: FOODS, store_id: CA_2
# Fold 0
# Train RMSE: 2.28759
# Test RMSE: 3.15882
# Fold 1
# Train RMSE: 2.29612
# Test RMSE: 3.04322
# Fold 2
# Train RMSE: 2.29828
# Test RMSE: 2.87387
# Fold 3
# Train RMSE: 2.30160
# Test RMSE: 2.76297
# Fold 4
# Train RMSE: 2.30741
# Test RMSE: 2.46620
# OOF RMSE: 2.87122
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 1.16736
# cat_id: HOBBIES, store_id: CA_3
# Fold 0
# Train RMSE: 2.38907
# Test RMSE: 2.33998
# Fold 1
# Train RMSE: 2.39442
# Test RMSE: 2.27604
# Fold 2
# Train RMSE: 2.39679
# Test RMSE: 2.28353
# Fold 3
# Train RMSE: 2.39662
# Test RMSE: 2.26883
# Fold 4
# Train RMSE: 2.39546
# Test RMSE: 2.23413
# OOF RMSE: 2.28080
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.75085
# cat_id: HOUSEHOLD, store_id: CA_3
# Fold 0
# Train RMSE: 2.14907
# Test RMSE: 2.49805
# Fold 1
# Train RMSE: 2.14612
# Test RMSE: 2.49300
# Fold 2
# Train RMSE: 2.14547
# Test RMSE: 2.45691
# Fold 3
# Train RMSE: 2.14607
# Test RMSE: 2.28000
# Fold 4
# Train RMSE: 2.14719
# Test RMSE: 2.15776
# OOF RMSE: 2.38119
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.82276
# cat_id: FOODS, store_id: CA_3
# Fold 0
# Train RMSE: 4.81238
# Test RMSE: 4.80450
# Fold 1
# Train RMSE: 4.80525
# Test RMSE: 4.27531
# Fold 2
# Train RMSE: 4.78902
# Test RMSE: 3.80283
# Fold 3
# Train RMSE: 4.77466
# Test RMSE: 3.87515
# Fold 4
# Train RMSE: 4.75984
# Test RMSE: 3.20308
# OOF RMSE: 4.02801
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.90789
# cat_id: HOBBIES, store_id: CA_4
# Fold 0
# Train RMSE: 1.54192
# Test RMSE: 1.59283
# Fold 1
# Train RMSE: 1.54488
# Test RMSE: 1.59204
# Fold 2
# Train RMSE: 1.54896
# Test RMSE: 1.58480
# Fold 3
# Train RMSE: 1.55253
# Test RMSE: 1.58098
# Fold 4
# Train RMSE: 1.55223
# Test RMSE: 1.56770
# OOF RMSE: 1.58373
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.91949
# cat_id: HOUSEHOLD, store_id: CA_4
# Fold 0
# Train RMSE: 0.76598
# Test RMSE: 0.93205
# Fold 1
# Train RMSE: 0.76773
# Test RMSE: 0.92386
# Fold 2
# Train RMSE: 0.76853
# Test RMSE: 0.90419
# Fold 3
# Train RMSE: 0.76945
# Test RMSE: 0.89651
# Fold 4
# Train RMSE: 0.77118
# Test RMSE: 0.87897
# OOF RMSE: 0.90732
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 1.38955
# cat_id: FOODS, store_id: CA_4
# Fold 0
# Train RMSE: 1.74075
# Test RMSE: 1.96316
# Fold 1
# Train RMSE: 1.73922
# Test RMSE: 1.86939
# Fold 2
# Train RMSE: 1.73756
# Test RMSE: 1.82505
# Fold 3
# Train RMSE: 1.73609
# Test RMSE: 1.73733
# Fold 4
# Train RMSE: 1.73563
# Test RMSE: 1.64702
# OOF RMSE: 1.81173
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 1.03945
# cat_id: HOBBIES, store_id: TX_1
# Fold 0
# Train RMSE: 1.31602
# Test RMSE: 1.49785
# Fold 1
# Train RMSE: 1.32043
# Test RMSE: 1.46792
# Fold 2
# Train RMSE: 1.32352
# Test RMSE: 1.47464
# Fold 3
# Train RMSE: 1.32506
# Test RMSE: 1.42787
# Fold 4
# Train RMSE: 1.32664
# Test RMSE: 1.40592
# OOF RMSE: 1.45523
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.89783
# cat_id: HOUSEHOLD, store_id: TX_1
# Fold 0
# Train RMSE: 1.46272
# Test RMSE: 1.53315
# Fold 1
# Train RMSE: 1.46280
# Test RMSE: 1.43332
# Fold 2
# Train RMSE: 1.46087
# Test RMSE: 1.39108
# Fold 3
# Train RMSE: 1.45996
# Test RMSE: 1.37883
# Fold 4
# Train RMSE: 1.45890
# Test RMSE: 1.33497
# OOF RMSE: 1.41592
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.92065
# cat_id: FOODS, store_id: TX_1
# Fold 0
# Train RMSE: 2.75396
# Test RMSE: 2.84947
# Fold 1
# Train RMSE: 2.75094
# Test RMSE: 2.64167
# Fold 2
# Train RMSE: 2.74436
# Test RMSE: 2.36452
# Fold 3
# Train RMSE: 2.73528
# Test RMSE: 2.34851
# Fold 4
# Train RMSE: 2.72897
# Test RMSE: 2.05741
# OOF RMSE: 2.46773
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 1.08986
# cat_id: HOBBIES, store_id: TX_2
# Fold 0
# Train RMSE: 1.54218
# Test RMSE: 1.57431
# Fold 1
# Train RMSE: 1.54077
# Test RMSE: 1.56475
# Fold 2
# Train RMSE: 1.53925
# Test RMSE: 1.55356
# Fold 3
# Train RMSE: 1.53807
# Test RMSE: 1.54184
# Fold 4
# Train RMSE: 1.53636
# Test RMSE: 1.52214
# OOF RMSE: 1.55143
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.98970
# cat_id: HOUSEHOLD, store_id: TX_2
# Fold 0
# Train RMSE: 1.83528
# Test RMSE: 1.71810
# Fold 1
# Train RMSE: 1.83259
# Test RMSE: 1.71206
# Fold 2
# Train RMSE: 1.82902
# Test RMSE: 1.56982
# Fold 3
# Train RMSE: 1.82450
# Test RMSE: 1.56367
# Fold 4
# Train RMSE: 1.81972
# Test RMSE: 1.44854
# OOF RMSE: 1.60594
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.79832
# cat_id: FOODS, store_id: TX_2
# Fold 0
# Train RMSE: 3.30267
# Test RMSE: 3.33915
# Fold 1
# Train RMSE: 3.29951
# Test RMSE: 2.91127
# Fold 2
# Train RMSE: 3.29270
# Test RMSE: 2.68433
# Fold 3
# Train RMSE: 3.28377
# Test RMSE: 2.48982
# Fold 4
# Train RMSE: 3.27317
# Test RMSE: 2.28018
# OOF RMSE: 2.76562
#   0%|          | 0/12 [00:00<?, ?it/s]
# OOF WRMSSE: 0.79987
# cat_id: HOBBIES, store_id: TX_3
# Fold 0
# Train RMSE: 1.33960
# Test RMSE: 1.56595
# Fold 1

# %%
'''
Fold 0
Train RMSE: 2.30
Test RMSE: 2.26
Fold 1
Train RMSE: 2.30
Test RMSE: 2.21
Fold 2
Train RMSE: 2.30
Test RMSE: 2.21
Fold 3
Train RMSE: 2.30
Test RMSE: 2.19
Fold 4
Train RMSE: 2.30
Test RMSE: 2.18
OOF RMSE: 2.21
100%
12/12 [00:00<00:00, 100.56it/s]
OOF WRMSSE: 0.81
CPU times: user 19min 53s, sys: 11.9 s, total: 20min 5s
Wall time: 3min 2s
'''
# Out:
# '\nFold 0\nTrain RMSE: 2.30\nTest RMSE: 2.26\nFold 1\nTrain RMSE: 2.30\nTest RMSE: 2.21\nFold 2\nTrain RMSE: 2.30\nTest RMSE: 2.21\nFold 3\nTrain RMSE: 2.30\nTest RMSE: 2.19\nFold 4\nTrain RMSE: 2.30\nTest RMSE: 2.18\nOOF RMSE: 2.21\n100%\n12/12 [00:00<00:00, 100.56it/s]\nOOF WRMSSE: 0.81\nCPU times: user 19min 53s, sys: 11.9 s, total: 20min 5s\nWall time: 3min 2s\n'
